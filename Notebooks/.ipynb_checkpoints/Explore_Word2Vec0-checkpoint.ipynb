# %% [markdown]
# # Exploration der Word2vec Embeddings 0

# %% [markdown]
# - ohne Bigramme
# - vector_size: 300
# - window: 10
# - seed: 42

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import statistics 

from collections import Counter
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from scipy import spatial
from sklearn.manifold import TSNE
from tabulate import tabulate

# %%
# trainierte Modelle laden

w2v1 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v1.model'))
w2v2 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v2.model'))
w2v3 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v3.model'))
w2v4 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v4.model'))
w2v5 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v5.model'))
w2v6 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v6.model'))
w2v7 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v7.model'))
w2v8 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v8.model'))
w2v9 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v9.model'))
w2v10 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v10.model'))
w2v11 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v11.model'))
w2v12 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v12.model'))
w2v13 = Word2Vec.load(os.path.join('../trained_models/Word2Vec0', 'w2v13.model'))

# %%
periods = ['1700-1750', '1751-1800', '1801-1825', '1826-1850', '1851-1875', '1876-1900', '1901-1925', 
          '1926-1950', '1951-1975', '1976-2000', '2001-2010', '2011-2016', '2017-2021']

# %%
models = [w2v1, w2v2, w2v3, w2v4, w2v5, w2v6, w2v7, w2v8, w2v9, w2v10, w2v11, w2v12, w2v13]

# %%
# Hilfsfunktion zum Vergleich der most similar words eines Lemmas in den Zeitabschnitten

def compare_words(periods, models, word):
    msw = {}
    for p, m in zip(periods, models):
        if word in m.wv:
            msw.update({p : m.wv.most_similar(positive=[word], topn=10)})
        elif word not in m.wv:
            msw.update({p : 'not in vocab'})
    table = pd.DataFrame.from_dict(msw)
    return table

# %%
# Hilfsfunktion zum Vergleich der Cosinus-Ähnlichkeit in den Zeitabschnitten

def compare_cos(periods, models, word1, word2):
    cosines = {}
    for p, m in zip(periods, models):
        if word1 in m.wv:
            vector1 = m.wv[word1]  
            vector2 = m.wv[word2]  
            cos = 1 - spatial.distance.cosine(vector1, vector2) 
            cosines.update({p : cos})
    return cosines

# %% [markdown]
# ### atrocemente

# %%
compare_words(periods, models, 'atrocemente')
# Out:
#                           1700-1750                            1751-1800  \
# 0   (impiumasi, 0.9840134382247925)    (irriverenza, 0.9873647689819336)
# 1      (accenn, 0.9827622771263123)         (fiacco, 0.9863688349723816)
# 2  (canzoncina, 0.9825814366340637)     (sviscerare, 0.9860110878944397)
# 3    (illumini, 0.9822802543640137)  (sbalordimento, 0.9859528541564941)
# 4     (stratti, 0.9819495677947998)       (mutilato, 0.9852686524391174)
# 5      (tienmi, 0.9819441437721252)    (discolparlo, 0.9851139783859253)
# 6    (seguilla, 0.9818325638771057)     (scioperali, 0.9850805997848511)
# 7    (confidati, 0.981825053691864)   (fluttuazione, 0.9849953651428223)
# 8    (ajutarlo, 0.9816318154335022)      (elevazion, 0.9849388599395752)
# 9  (accreditar, 0.9815068244934082)    (gesticolare, 0.9846347570419312)
#
#                             1801-1825                            1826-1850  \
# 0     (vigliacco, 0.9886707067489624)    (persecutore, 0.9357825517654419)
# ...

# %%
compare_cos(periods, models, 'atrocemente', 'molto')
# Out:
# {'1700-1750': 0.5248823165893555,
#  '1751-1800': 0.5594866871833801,
#  '1801-1825': 0.5923386216163635,
#  '1826-1850': 0.4354524314403534,
#  '1851-1875': 0.492401123046875,
#  '1876-1900': 0.37499627470970154,
#  '1901-1925': 0.3757375180721283,
#  '1926-1950': 0.3889538645744324,
#  '1951-1975': 0.4656788408756256,
#  '1976-2000': 0.40518808364868164,
#  '2001-2010': 0.3564792275428772,
#  '2011-2016': 0.30754637718200684,
#  '2017-2021': 0.3586801588535309}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'atrocemente', 'molto')
x_indexes = np.arange(len(data))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)
plt.plot(x_indexes, data.values(), label='atrocemente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'atrocemente', 'angoscia')
# Out:
# {'1700-1750': 0.7983745336532593,
#  '1751-1800': 0.6172037720680237,
#  '1801-1825': 0.6391586661338806,
#  '1826-1850': 0.4737037122249603,
#  '1851-1875': 0.5192838311195374,
#  '1876-1900': 0.3458266854286194,
#  '1901-1925': 0.44589731097221375,
#  '1926-1950': 0.5510258674621582,
#  '1951-1975': 0.8215969204902649,
#  '1976-2000': 0.39658164978027344,
#  '2001-2010': 0.5249975919723511,
#  '2011-2016': 0.5495206117630005,
#  '2017-2021': 0.5441070795059204}

# %%
compare_cos(periods, models, 'atrocemente', 'atterrire')
# Out:
# {'1700-1750': 0.5616060495376587,
#  '1751-1800': 0.6633084416389465,
#  '1801-1825': 0.7454069256782532,
#  '1826-1850': 0.5619803667068481,
#  '1851-1875': 0.5266431570053101,
#  '1876-1900': 0.3617197275161743,
#  '1901-1925': 0.5196764469146729,
#  '1926-1950': 0.6393945813179016,
#  '1951-1975': 0.8899676203727722,
#  '1976-2000': 0.521704912185669,
#  '2001-2010': 0.6249051094055176,
#  '2011-2016': 0.5824189782142639,
#  '2017-2021': 0.6208723783493042}

# %%
compare_cos(periods, models, 'atrocemente', 'panico')
# Out:
# {'1700-1750': 0.8012893795967102,
#  '1751-1800': 0.8335154056549072,
#  '1801-1825': 0.9397887587547302,
#  '1826-1850': 0.6326342225074768,
#  '1851-1875': 0.6056962013244629,
#  '1876-1900': 0.2905058264732361,
#  '1901-1925': 0.4491281807422638,
#  '1926-1950': 0.7541083693504333,
#  '1951-1975': 0.8912957906723022,
#  '1976-2000': 0.22984373569488525,
#  '2001-2010': 0.33956947922706604,
#  '2011-2016': 0.2702135741710663,
#  '2017-2021': 0.3136139512062073}

# %%
compare_cos(periods, models, 'atrocemente', 'paura')
# Out:
# {'1700-1750': 0.5126750469207764,
#  '1751-1800': 0.6019030213356018,
#  '1801-1825': 0.5825454592704773,
#  '1826-1850': 0.5227750539779663,
#  '1851-1875': 0.5179571509361267,
#  '1876-1900': 0.2898138165473938,
#  '1901-1925': 0.3921334445476532,
#  '1926-1950': 0.4335910379886627,
#  '1951-1975': 0.7498059272766113,
#  '1976-2000': 0.3314448893070221,
#  '2001-2010': 0.3995632231235504,
#  '2011-2016': 0.4104164242744446,
#  '2017-2021': 0.43070855736732483}

# %%
compare_cos(periods, models, 'atrocemente', 'raccapricciare')
# Out:
# {'1700-1750': 0.9352179169654846,
#  '1751-1800': 0.9528425335884094,
#  '1801-1825': 0.908842146396637,
#  '1826-1850': 0.7813831567764282,
#  '1851-1875': 0.6751192808151245,
#  '1876-1900': 0.39386990666389465,
#  '1901-1925': 0.6621798276901245,
#  '1926-1950': 0.8111156225204468,
#  '1951-1975': 0.8349122405052185,
#  '1976-2000': 0.5967406630516052,
#  '2001-2010': 0.6870697140693665,
#  '2011-2016': 0.6673396825790405,
#  '2017-2021': 0.6512985825538635}

# %%
compare_cos(periods, models, 'atrocemente', 'schifo')
# Out:
# {'1700-1750': 0.9199402332305908,
#  '1751-1800': 0.747026801109314,
#  '1801-1825': 0.9498815536499023,
#  '1826-1850': 0.8165737390518188,
#  '1851-1875': 0.5486565232276917,
#  '1876-1900': 0.28900548815727234,
#  '1901-1925': 0.546061098575592,
#  '1926-1950': 0.47794705629348755,
#  '1951-1975': 0.9362966418266296,
#  '1976-2000': 0.3614327907562256,
#  '2001-2010': 0.3275443911552429,
#  '2011-2016': 0.3451169431209564,
#  '2017-2021': 0.4126430153846741}

# %%
compare_cos(periods, models, 'atrocemente', 'sgomentare')
# Out:
# {'1700-1750': 0.7191365957260132,
#  '1751-1800': 0.8394245505332947,
#  '1801-1825': 0.8894480466842651,
#  '1826-1850': 0.6969040632247925,
#  '1851-1875': 0.49297237396240234,
#  '1876-1900': 0.33875933289527893,
#  '1901-1925': 0.548579216003418,
#  '1926-1950': 0.6904613971710205,
#  '1951-1975': 0.8768364787101746,
#  '1976-2000': 0.5016106963157654,
#  '2001-2010': 0.6259245872497559,
#  '2011-2016': 0.6111840605735779,
#  '2017-2021': 0.6572728157043457}

# %%
compare_cos(periods, models, 'atrocemente', 'sgomento')
# Out:
# {'1700-1750': 0.9158264398574829,
#  '1751-1800': 0.9480358958244324,
#  '1801-1825': 0.9376519918441772,
#  '1826-1850': 0.678609311580658,
#  '1851-1875': 0.550381064414978,
#  '1876-1900': 0.27218666672706604,
#  '1901-1925': 0.42786160111427307,
#  '1926-1950': 0.6222654581069946,
#  '1951-1975': 0.8491291403770447,
#  '1976-2000': 0.3543533682823181,
#  '2001-2010': 0.4308345317840576,
#  '2011-2016': 0.4522991478443146,
#  '2017-2021': 0.4857157766819}

# %%
compare_cos(periods, models, 'atrocemente', 'spaventare')
# Out:
# {'1700-1750': 0.5973538160324097,
#  '1751-1800': 0.594842255115509,
#  '1801-1825': 0.5692989230155945,
#  '1826-1850': 0.48185446858406067,
#  '1851-1875': 0.47665366530418396,
#  '1876-1900': 0.2800571024417877,
#  '1901-1925': 0.31399521231651306,
#  '1926-1950': 0.5907219052314758,
#  '1951-1975': 0.8468469381332397,
#  '1976-2000': 0.29699185490608215,
#  '2001-2010': 0.43466970324516296,
#  '2011-2016': 0.4303909242153168,
#  '2017-2021': 0.4723634421825409}

# %%
compare_cos(periods, models, 'atrocemente', 'spavento')
# Out:
# {'1700-1750': 0.4832303524017334,
#  '1751-1800': 0.5190091729164124,
#  '1801-1825': 0.6255770325660706,
#  '1826-1850': 0.36614853143692017,
#  '1851-1875': 0.49598580598831177,
#  '1876-1900': 0.28125864267349243,
#  '1901-1925': 0.4759840965270996,
#  '1926-1950': 0.568589985370636,
#  '1951-1975': 0.8918329477310181,
#  '1976-2000': 0.38201743364334106,
#  '2001-2010': 0.488075852394104,
#  '2011-2016': 0.43443331122398376,
#  '2017-2021': 0.44380128383636475}

# %%
compare_cos(periods, models, 'atrocemente', 'terrore')
# Out:
# {'1700-1750': 0.42480894923210144,
#  '1751-1800': 0.4420880973339081,
#  '1801-1825': 0.537773072719574,
#  '1826-1850': 0.35304027795791626,
#  '1851-1875': 0.43028077483177185,
#  '1876-1900': 0.2886689007282257,
#  '1901-1925': 0.367829829454422,
#  '1926-1950': 0.49756672978401184,
#  '1951-1975': 0.8266077041625977,
#  '1976-2000': 0.43899139761924744,
#  '2001-2010': 0.490951806306839,
#  '2011-2016': 0.44436749815940857,
#  '2017-2021': 0.5406708121299744}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'atrocemente', 'angoscia')
data2 = compare_cos(periods, models, 'atrocemente', 'atterrire')
data3 = compare_cos(periods, models, 'atrocemente', 'panico')
data4 = compare_cos(periods, models, 'atrocemente', 'paura')
data5 = compare_cos(periods, models, 'atrocemente', 'raccapricciare')
data6 = compare_cos(periods, models, 'atrocemente', 'schifo')
data7 = compare_cos(periods, models, 'atrocemente', 'sgomentare')
data8 = compare_cos(periods, models, 'atrocemente', 'sgomento')
data9 = compare_cos(periods, models, 'atrocemente', 'spaventare')
data10 = compare_cos(periods, models, 'atrocemente', 'spavento')
data11 = compare_cos(periods, models, 'atrocemente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### formidabilmente

# %%
compare_words(periods, models, 'formidabilmente')
# Out:
#       1700-1750     1751-1800     1801-1825  \
# 0  not in vocab  not in vocab  not in vocab
# 1  not in vocab  not in vocab  not in vocab
# 2  not in vocab  not in vocab  not in vocab
# 3  not in vocab  not in vocab  not in vocab
# 4  not in vocab  not in vocab  not in vocab
# 5  not in vocab  not in vocab  not in vocab
# 6  not in vocab  not in vocab  not in vocab
# 7  not in vocab  not in vocab  not in vocab
# 8  not in vocab  not in vocab  not in vocab
# 9  not in vocab  not in vocab  not in vocab
#
#                                 1826-1850                          1851-1875  \
# 0            (babele, 0.9852179288864136)    (racchiuso, 0.9539878368377686)
# 1           (elegger, 0.9843016862869263)  (promontorii, 0.9529997706413269)
# 2  (territorialmente, 0.9828386902809143)      (convesso, 0.952193558216095)
# 3       (nimichevole, 0.9827989339828491)       (riseghe, 0.948635458946228)
# 4          (metatesi, 0.9825443029403687)    (cesellato, 0.9474702477455139)
# ...

# %%
compare_cos(periods, models, 'formidabilmente', 'molto')
# Out:
# {'1826-1850': 0.5255387425422668,
#  '1851-1875': 0.4419073462486267,
#  '1876-1900': 0.5376014113426208,
#  '1901-1925': 0.4025053083896637,
#  '1926-1950': 0.4758678674697876,
#  '1976-2000': 0.5538356304168701,
#  '2001-2010': 0.47907277941703796,
#  '2011-2016': 0.5179849863052368,
#  '2017-2021': 0.5049660801887512}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'formidabilmente', 'molto')
x_indexes = np.arange(len(data))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)
plt.plot(x_indexes, data.values(), label='atrocemente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'formidabilmente', 'angoscia')
# Out:
# {'1826-1850': 0.47041451930999756,
#  '1851-1875': 0.31795749068260193,
#  '1876-1900': 0.44776543974876404,
#  '1901-1925': 0.2683001756668091,
#  '1926-1950': 0.35161009430885315,
#  '1976-2000': 0.38616862893104553,
#  '2001-2010': 0.47103381156921387,
#  '2011-2016': 0.5105487704277039,
#  '2017-2021': 0.49078261852264404}

# %%
compare_cos(periods, models, 'formidabilmente', 'atterrire')
# Out:
# {'1826-1850': 0.4635339677333832,
#  '1851-1875': 0.2983630895614624,
#  '1876-1900': 0.44054049253463745,
#  '1901-1925': 0.4656742811203003,
#  '1926-1950': 0.44248709082603455,
#  '1976-2000': 0.4537333846092224,
#  '2001-2010': 0.5566400289535522,
#  '2011-2016': 0.5107510685920715,
#  '2017-2021': 0.5504646897315979}

# %%
compare_cos(periods, models, 'formidabilmente', 'panico')
# Out:
# {'1826-1850': 0.6239618062973022,
#  '1851-1875': 0.5285195708274841,
#  '1876-1900': 0.48010000586509705,
#  '1901-1925': 0.48982277512550354,
#  '1926-1950': 0.5392881035804749,
#  '1976-2000': 0.3173295855522156,
#  '2001-2010': 0.3322599232196808,
#  '2011-2016': 0.39910390973091125,
#  '2017-2021': 0.2978765368461609}

# %%
compare_cos(periods, models, 'formidabilmente', 'paura')
# Out:
# {'1826-1850': 0.43543481826782227,
#  '1851-1875': 0.23944655060768127,
#  '1876-1900': 0.3368050754070282,
#  '1901-1925': 0.2521999478340149,
#  '1926-1950': 0.30218517780303955,
#  '1976-2000': 0.38357317447662354,
#  '2001-2010': 0.36216527223587036,
#  '2011-2016': 0.4444696009159088,
#  '2017-2021': 0.36864838004112244}

# %%
compare_cos(periods, models, 'formidabilmente', 'raccapricciare')
# Out:
# {'1826-1850': 0.6919841766357422,
#  '1851-1875': 0.5950137972831726,
#  '1876-1900': 0.5996853113174438,
#  '1901-1925': 0.6036707162857056,
#  '1926-1950': 0.7978216409683228,
#  '1976-2000': 0.8558960556983948,
#  '2001-2010': 0.6471378207206726,
#  '2011-2016': 0.7914243340492249,
#  '2017-2021': 0.6707026958465576}

# %%
compare_cos(periods, models, 'formidabilmente', 'schifo')
# Out:
# {'1826-1850': 0.7643861174583435,
#  '1851-1875': 0.5645021200180054,
#  '1876-1900': 0.35040295124053955,
#  '1901-1925': 0.4747683107852936,
#  '1926-1950': 0.4908623993396759,
#  '1976-2000': 0.309853196144104,
#  '2001-2010': 0.11927872151136398,
#  '2011-2016': 0.3650069236755371,
#  '2017-2021': 0.25454965233802795}

# %%
compare_cos(periods, models, 'formidabilmente', 'sgomentare')
# Out:
# {'1826-1850': 0.6044973731040955,
#  '1851-1875': 0.355241596698761,
#  '1876-1900': 0.3780752420425415,
#  '1901-1925': 0.46892470121383667,
#  '1926-1950': 0.4713064730167389,
#  '1976-2000': 0.4644935429096222,
#  '2001-2010': 0.5719977021217346,
#  '2011-2016': 0.5745424032211304,
#  '2017-2021': 0.6035383939743042}

# %%
compare_cos(periods, models, 'formidabilmente', 'sgomento')
# Out:
# {'1826-1850': 0.6807758808135986,
#  '1851-1875': 0.34034422039985657,
#  '1876-1900': 0.4521039128303528,
#  '1901-1925': 0.34814924001693726,
#  '1926-1950': 0.3953762352466583,
#  '1976-2000': 0.3794998824596405,
#  '2001-2010': 0.3922770023345947,
#  '2011-2016': 0.40062159299850464,
#  '2017-2021': 0.4122806787490845}

# %%
compare_cos(periods, models, 'formidabilmente', 'spaventare')
# Out:
# {'1826-1850': 0.41491642594337463,
#  '1851-1875': 0.26436421275138855,
#  '1876-1900': 0.35788020491600037,
#  '1901-1925': 0.3171193301677704,
#  '1926-1950': 0.4086195230484009,
#  '1976-2000': 0.3288361132144928,
#  '2001-2010': 0.3956034481525421,
#  '2011-2016': 0.4902777373790741,
#  '2017-2021': 0.45405107736587524}

# %%
compare_cos(periods, models, 'formidabilmente', 'spavento')
# Out:
# {'1826-1850': 0.39816591143608093,
#  '1851-1875': 0.26803216338157654,
#  '1876-1900': 0.38942664861679077,
#  '1901-1925': 0.2817789316177368,
#  '1926-1950': 0.37909361720085144,
#  '1976-2000': 0.3241749107837677,
#  '2001-2010': 0.3875965476036072,
#  '2011-2016': 0.4842403829097748,
#  '2017-2021': 0.3931933641433716}

# %%
compare_cos(periods, models, 'formidabilmente', 'terrore')
# Out:
# {'1826-1850': 0.3221186697483063,
#  '1851-1875': 0.2636631429195404,
#  '1876-1900': 0.33853602409362793,
#  '1901-1925': 0.29664695262908936,
#  '1926-1950': 0.3247380256652832,
#  '1976-2000': 0.38407063484191895,
#  '2001-2010': 0.42268502712249756,
#  '2011-2016': 0.4601248502731323,
#  '2017-2021': 0.48037227988243103}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'formidabilmente', 'angoscia')
data2 = compare_cos(periods, models, 'formidabilmente', 'atterrire')
data3 = compare_cos(periods, models, 'formidabilmente', 'panico')
data4 = compare_cos(periods, models, 'formidabilmente', 'paura')
data5 = compare_cos(periods, models, 'formidabilmente', 'raccapricciare')
data6 = compare_cos(periods, models, 'formidabilmente', 'schifo')
data7 = compare_cos(periods, models, 'formidabilmente', 'sgomentare')
data8 = compare_cos(periods, models, 'formidabilmente', 'sgomento')
data9 = compare_cos(periods, models, 'formidabilmente', 'spaventare')
data10 = compare_cos(periods, models, 'formidabilmente', 'spavento')
data11 = compare_cos(periods, models, 'formidabilmente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### mostruosamente

# %%
compare_words(periods, models, 'mostruosamente')
# Out:
#                             1700-1750     1751-1800  \
# 0     (deformare, 0.9895263910293579)  not in vocab
# 1      (infranse, 0.9794477820396423)  not in vocab
# 2  (vacillamento, 0.9792865514755249)  not in vocab
# 3        (accost, 0.9781127572059631)  not in vocab
# 4         (avisi, 0.9779921174049377)  not in vocab
# 5       (ispezie, 0.9775084257125854)  not in vocab
# 6    (infingardi, 0.9770423173904419)  not in vocab
# 7         (puoté, 0.9767104387283325)  not in vocab
# 8       (cruento, 0.9767040014266968)  not in vocab
# 9        (assano, 0.9765947461128235)  not in vocab
#
#                             1801-1825                            1826-1850  \
# 0       (rilento, 0.9889542460441589)       (benevoli, 0.9729883670806885)
# 1          (meri, 0.9884401559829712)        (gaiezza, 0.9726594686508179)
# 2           (neg, 0.9883047938346863)  (paradossastico, 0.972378134727478)
# 3     (andreuccio, 0.988017737865448)        (dessere, 0.9722349643707275)
# ...

# %%
compare_cos(periods, models, 'mostruosamente', 'molto')
# Out:
# {'1700-1750': 0.5438158512115479,
#  '1801-1825': 0.6063828468322754,
#  '1826-1850': 0.5310093760490417,
#  '1851-1875': 0.6127738952636719,
#  '1876-1900': 0.43056413531303406,
#  '1901-1925': 0.47200796008110046,
#  '1926-1950': 0.3397800624370575,
#  '1951-1975': 0.5544949769973755,
#  '1976-2000': 0.6010770201683044,
#  '2001-2010': 0.5046929717063904,
#  '2011-2016': 0.48601409792900085,
#  '2017-2021': 0.4650530517101288}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'mostruosamente', 'molto')
x_indexes = np.arange(len(data))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)
plt.plot(x_indexes, data.values(), label='mostruosamente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'mostruosamente', 'angoscia')
# Out:
# {'1700-1750': 0.7276809215545654,
#  '1801-1825': 0.5815832614898682,
#  '1826-1850': 0.4011267125606537,
#  '1851-1875': 0.4362247884273529,
#  '1876-1900': 0.4243713915348053,
#  '1901-1925': 0.3851293921470642,
#  '1926-1950': 0.33923885226249695,
#  '1951-1975': 0.7239967584609985,
#  '1976-2000': 0.314786821603775,
#  '2001-2010': 0.421827495098114,
#  '2011-2016': 0.37194687128067017,
#  '2017-2021': 0.4195079505443573}

# %%
compare_cos(periods, models, 'mostruosamente', 'atterrire')
# Out:
# {'1700-1750': 0.512410581111908,
#  '1801-1825': 0.63295978307724,
#  '1826-1850': 0.4039275050163269,
#  '1851-1875': 0.3903064727783203,
#  '1876-1900': 0.3249986469745636,
#  '1901-1925': 0.4330974519252777,
#  '1926-1950': 0.43299606442451477,
#  '1951-1975': 0.9048464298248291,
#  '1976-2000': 0.5112237930297852,
#  '2001-2010': 0.447447270154953,
#  '2011-2016': 0.3587183654308319,
#  '2017-2021': 0.4884130656719208}

# %%
compare_cos(periods, models, 'mostruosamente', 'panico')
# Out:
# {'1700-1750': 0.7730473279953003,
#  '1801-1825': 0.9101008772850037,
#  '1826-1850': 0.5163532495498657,
#  '1851-1875': 0.5662012100219727,
#  '1876-1900': 0.3958360254764557,
#  '1901-1925': 0.4761015772819519,
#  '1926-1950': 0.501737654209137,
#  '1951-1975': 0.8555086851119995,
#  '1976-2000': 0.23554466664791107,
#  '2001-2010': 0.218536376953125,
#  '2011-2016': 0.22953926026821136,
#  '2017-2021': 0.2433454394340515}

# %%
compare_cos(periods, models, 'mostruosamente', 'paura')
# Out:
# {'1700-1750': 0.41939252614974976,
#  '1801-1825': 0.5131357312202454,
#  '1826-1850': 0.40937280654907227,
#  '1851-1875': 0.3963542580604553,
#  '1876-1900': 0.2591250538825989,
#  '1901-1925': 0.3250623345375061,
#  '1926-1950': 0.280433714389801,
#  '1951-1975': 0.6061116456985474,
#  '1976-2000': 0.29450172185897827,
#  '2001-2010': 0.32101646065711975,
#  '2011-2016': 0.2815568149089813,
#  '2017-2021': 0.3561868965625763}

# %%
compare_cos(periods, models, 'mostruosamente', 'raccapricciare')
# Out:
# {'1700-1750': 0.9134448766708374,
#  '1801-1825': 0.8791735172271729,
#  '1826-1850': 0.713091254234314,
#  '1851-1875': 0.6794423460960388,
#  '1876-1900': 0.4136181175708771,
#  '1901-1925': 0.6790900826454163,
#  '1926-1950': 0.6900486946105957,
#  '1951-1975': 0.9455505609512329,
#  '1976-2000': 0.6116886734962463,
#  '2001-2010': 0.585012674331665,
#  '2011-2016': 0.6057763695716858,
#  '2017-2021': 0.5212646126747131}

# %%
compare_cos(periods, models, 'mostruosamente', 'schifo')
# Out:
# {'1700-1750': 0.9022811651229858,
#  '1801-1825': 0.9530937075614929,
#  '1826-1850': 0.7615524530410767,
#  '1851-1875': 0.5255566239356995,
#  '1876-1900': 0.36239176988601685,
#  '1901-1925': 0.5123599767684937,
#  '1926-1950': 0.34546878933906555,
#  '1951-1975': 0.849409282207489,
#  '1976-2000': 0.29993125796318054,
#  '2001-2010': 0.432438462972641,
#  '2011-2016': 0.429185152053833,
#  '2017-2021': 0.4654233455657959}

# %%
compare_cos(periods, models, 'mostruosamente', 'sgomentare')
# Out:
# {'1700-1750': 0.6216720938682556,
#  '1801-1825': 0.8789963126182556,
#  '1826-1850': 0.5750290155410767,
#  '1851-1875': 0.5163688063621521,
#  '1876-1900': 0.3414177894592285,
#  '1901-1925': 0.5687477588653564,
#  '1926-1950': 0.5151877999305725,
#  '1951-1975': 0.8919680118560791,
#  '1976-2000': 0.407684862613678,
#  '2001-2010': 0.500207245349884,
#  '2011-2016': 0.4172746241092682,
#  '2017-2021': 0.5124444961547852}

# %%
compare_cos(periods, models, 'mostruosamente', 'sgomento')
# Out:
# {'1700-1750': 0.9205948710441589,
#  '1801-1825': 0.9213595390319824,
#  '1826-1850': 0.6222511529922485,
#  '1851-1875': 0.4992440342903137,
#  '1876-1900': 0.3611152172088623,
#  '1901-1925': 0.4885297417640686,
#  '1926-1950': 0.3913023769855499,
#  '1951-1975': 0.7987917065620422,
#  '1976-2000': 0.28034862875938416,
#  '2001-2010': 0.352522075176239,
#  '2011-2016': 0.27801260352134705,
#  '2017-2021': 0.3649970591068268}

# %%
compare_cos(periods, models, 'mostruosamente', 'spaventare')
# Out:
# {'1700-1750': 0.558597981929779,
#  '1801-1825': 0.5175079703330994,
#  '1826-1850': 0.3621530532836914,
#  '1851-1875': 0.3956470489501953,
#  '1876-1900': 0.19092391431331635,
#  '1901-1925': 0.34873756766319275,
#  '1926-1950': 0.36693471670150757,
#  '1951-1975': 0.7197147607803345,
#  '1976-2000': 0.34154683351516724,
#  '2001-2010': 0.4332400858402252,
#  '2011-2016': 0.4289369583129883,
#  '2017-2021': 0.4760109782218933}

# %%
compare_cos(periods, models, 'mostruosamente', 'spavento')
# Out:
# {'1700-1750': 0.45312613248825073,
#  '1801-1825': 0.5303903222084045,
#  '1826-1850': 0.3189558982849121,
#  '1851-1875': 0.4335114061832428,
#  '1876-1900': 0.3248021602630615,
#  '1901-1925': 0.4115249514579773,
#  '1926-1950': 0.4051964282989502,
#  '1951-1975': 0.7721238136291504,
#  '1976-2000': 0.37413084506988525,
#  '2001-2010': 0.4175626337528229,
#  '2011-2016': 0.4288960099220276,
#  '2017-2021': 0.4679444432258606}

# %%
compare_cos(periods, models, 'mostruosamente', 'terrore')
# Out:
# {'1700-1750': 0.4234376549720764,
#  '1801-1825': 0.4586975872516632,
#  '1826-1850': 0.27265632152557373,
#  '1851-1875': 0.39696329832077026,
#  '1876-1900': 0.2842469811439514,
#  '1901-1925': 0.40957802534103394,
#  '1926-1950': 0.3538576364517212,
#  '1951-1975': 0.6706628799438477,
#  '1976-2000': 0.27379927039146423,
#  '2001-2010': 0.313728392124176,
#  '2011-2016': 0.31347525119781494,
#  '2017-2021': 0.4145132601261139}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'mostruosamente', 'angoscia')
data2 = compare_cos(periods, models, 'mostruosamente', 'atterrire')
data3 = compare_cos(periods, models, 'mostruosamente', 'panico')
data4 = compare_cos(periods, models, 'mostruosamente', 'paura')
data5 = compare_cos(periods, models, 'mostruosamente', 'raccapricciare')
data6 = compare_cos(periods, models, 'mostruosamente', 'schifo')
data7 = compare_cos(periods, models, 'mostruosamente', 'sgomentare')
data8 = compare_cos(periods, models, 'mostruosamente', 'sgomento')
data9 = compare_cos(periods, models, 'mostruosamente', 'spaventare')
data10 = compare_cos(periods, models, 'mostruosamente', 'spavento')
data11 = compare_cos(periods, models, 'mostruosamente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### orrendamente

# %%
compare_words(periods, models, 'orrendamente')
# Out:
#       1700-1750     1751-1800                       1801-1825  \
# 0  not in vocab  not in vocab   (solcare, 0.9776529669761658)
# 1  not in vocab  not in vocab    (nugolo, 0.9747305512428284)
# 2  not in vocab  not in vocab  (spumante, 0.9712846875190735)
# 3  not in vocab  not in vocab     (rombo, 0.9701493382453918)
# 4  not in vocab  not in vocab   (spandea, 0.9694345593452454)
# 5  not in vocab  not in vocab    (spezzato, 0.96883225440979)
# 6  not in vocab  not in vocab      (balze, 0.968288004398346)
# 7  not in vocab  not in vocab   (susurro, 0.9681539535522461)
# 8  not in vocab  not in vocab  (appresta, 0.9673120379447937)
# 9  not in vocab  not in vocab  (sibilare, 0.9667467474937439)
#
#                          1826-1850                         1851-1875  \
# 0     (sparto, 0.9443144202232361)    (dilatato, 0.9166573286056519)
# 1     (averno, 0.9426371455192566)   (inumidire, 0.9033035039901733)
# 2     (pugnal, 0.9404156804084778)  (stravolgere, 0.902899980545044)
# ...

# %%
compare_cos(periods, models, 'orrendamente', 'molto')
# Out:
# {'1801-1825': 0.48858848214149475,
#  '1826-1850': 0.4141228497028351,
#  '1851-1875': 0.434998095035553,
#  '1876-1900': 0.32371681928634644,
#  '1901-1925': 0.3173811137676239,
#  '1926-1950': 0.3706229329109192,
#  '1951-1975': 0.4197736084461212,
#  '1976-2000': 0.26609012484550476,
#  '2001-2010': 0.2740868926048279,
#  '2011-2016': 0.25577959418296814,
#  '2017-2021': 0.2583959400653839}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'orrendamente', 'molto')
x_indexes = np.arange(len(data))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)
plt.plot(x_indexes, data.values(), label='orrendamente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'orrendamente', 'angoscia')
# Out:
# {'1801-1825': 0.6529176235198975,
#  '1826-1850': 0.5614936351776123,
#  '1851-1875': 0.532817006111145,
#  '1876-1900': 0.39486634731292725,
#  '1901-1925': 0.42268460988998413,
#  '1926-1950': 0.43709424138069153,
#  '1951-1975': 0.6255614161491394,
#  '1976-2000': 0.2609902024269104,
#  '2001-2010': 0.43894341588020325,
#  '2011-2016': 0.44751524925231934,
#  '2017-2021': 0.46755653619766235}

# %%
compare_cos(periods, models, 'orrendamente', 'atterrire')
# Out:
# {'1801-1825': 0.756904661655426,
#  '1826-1850': 0.47217854857444763,
#  '1851-1875': 0.47229015827178955,
#  '1876-1900': 0.41758492588996887,
#  '1901-1925': 0.47959375381469727,
#  '1926-1950': 0.5267274975776672,
#  '1951-1975': 0.9555161595344543,
#  '1976-2000': 0.4739825129508972,
#  '2001-2010': 0.5656474828720093,
#  '2011-2016': 0.5694780349731445,
#  '2017-2021': 0.5917425155639648}

# %%
compare_cos(periods, models, 'orrendamente', 'panico')
# Out:
# {'1801-1825': 0.8586030602455139,
#  '1826-1850': 0.5941609144210815,
#  '1851-1875': 0.5710728764533997,
#  '1876-1900': 0.41873255372047424,
#  '1901-1925': 0.4707029461860657,
#  '1926-1950': 0.6280131340026855,
#  '1951-1975': 0.7079638838768005,
#  '1976-2000': 0.19200439751148224,
#  '2001-2010': 0.2667398452758789,
#  '2011-2016': 0.23927561938762665,
#  '2017-2021': 0.2619245946407318}

# %%
compare_cos(periods, models, 'orrendamente', 'paura')
# Out:
# {'1801-1825': 0.574301540851593,
#  '1826-1850': 0.41961321234703064,
#  '1851-1875': 0.42057210206985474,
#  '1876-1900': 0.38525861501693726,
#  '1901-1925': 0.3187022805213928,
#  '1926-1950': 0.33081403374671936,
#  '1951-1975': 0.6376354694366455,
#  '1976-2000': 0.20205548405647278,
#  '2001-2010': 0.343065470457077,
#  '2011-2016': 0.28341132402420044,
#  '2017-2021': 0.36481669545173645}

# %%
compare_cos(periods, models, 'orrendamente', 'raccapricciare')
# Out:
# {'1801-1825': 0.8951594233512878,
#  '1826-1850': 0.7458179593086243,
#  '1851-1875': 0.8099430203437805,
#  '1876-1900': 0.5436563491821289,
#  '1901-1925': 0.5372327566146851,
#  '1926-1950': 0.8142260909080505,
#  '1951-1975': 0.9580662250518799,
#  '1976-2000': 0.5285255908966064,
#  '2001-2010': 0.6195136904716492,
#  '2011-2016': 0.6847604513168335,
#  '2017-2021': 0.6696391105651855}

# %%
compare_cos(periods, models, 'orrendamente', 'schifo')
# Out:
# {'1801-1825': 0.830305814743042,
#  '1826-1850': 0.7515160441398621,
#  '1851-1875': 0.6662998795509338,
#  '1876-1900': 0.40861204266548157,
#  '1901-1925': 0.5835732817649841,
#  '1926-1950': 0.4749048352241516,
#  '1951-1975': 0.8421858549118042,
#  '1976-2000': 0.275846004486084,
#  '2001-2010': 0.431252121925354,
#  '2011-2016': 0.3536795675754547,
#  '2017-2021': 0.36207932233810425}

# %%
compare_cos(periods, models, 'orrendamente', 'sgomentare')
# Out:
# {'1801-1825': 0.752781331539154,
#  '1826-1850': 0.43983379006385803,
#  '1851-1875': 0.42563533782958984,
#  '1876-1900': 0.45290255546569824,
#  '1901-1925': 0.4328683018684387,
#  '1926-1950': 0.5775159001350403,
#  '1951-1975': 0.9574238061904907,
#  '1976-2000': 0.4027189314365387,
#  '2001-2010': 0.5990474820137024,
#  '2011-2016': 0.5807445049285889,
#  '2017-2021': 0.5646512508392334}

# %%
compare_cos(periods, models, 'orrendamente', 'sgomento')
# Out:
# {'1801-1825': 0.9192790389060974,
#  '1826-1850': 0.699580192565918,
#  '1851-1875': 0.5474059581756592,
#  '1876-1900': 0.34534355998039246,
#  '1901-1925': 0.43769603967666626,
#  '1926-1950': 0.48044997453689575,
#  '1951-1975': 0.755710244178772,
#  '1976-2000': 0.3146973252296448,
#  '2001-2010': 0.4470469355583191,
#  '2011-2016': 0.40783601999282837,
#  '2017-2021': 0.4483042061328888}

# %%
compare_cos(periods, models, 'orrendamente', 'spaventare')
# Out:
# {'1801-1825': 0.5829071998596191,
#  '1826-1850': 0.3950166404247284,
#  '1851-1875': 0.43389829993247986,
#  '1876-1900': 0.32547080516815186,
#  '1901-1925': 0.33819594979286194,
#  '1926-1950': 0.44384893774986267,
#  '1951-1975': 0.8081563711166382,
#  '1976-2000': 0.21558350324630737,
#  '2001-2010': 0.4241398274898529,
#  '2011-2016': 0.42298445105552673,
#  '2017-2021': 0.42720457911491394}

# %%
compare_cos(periods, models, 'orrendamente', 'spavento')
# Out:
# {'1801-1825': 0.6930796504020691,
#  '1826-1850': 0.45604634284973145,
#  '1851-1875': 0.4891066253185272,
#  '1876-1900': 0.44678646326065063,
#  '1901-1925': 0.4908234179019928,
#  '1926-1950': 0.4723944664001465,
#  '1951-1975': 0.8234123587608337,
#  '1976-2000': 0.34303590655326843,
#  '2001-2010': 0.4650373160839081,
#  '2011-2016': 0.5055193305015564,
#  '2017-2021': 0.451976478099823}

# %%
compare_cos(periods, models, 'orrendamente', 'terrore')
# Out:
# {'1801-1825': 0.5573240518569946,
#  '1826-1850': 0.38318273425102234,
#  '1851-1875': 0.436587393283844,
#  '1876-1900': 0.2874336838722229,
#  '1901-1925': 0.4632475972175598,
#  '1926-1950': 0.4081023037433624,
#  '1951-1975': 0.6378058195114136,
#  '1976-2000': 0.30790701508522034,
#  '2001-2010': 0.47540614008903503,
#  '2011-2016': 0.3996332585811615,
#  '2017-2021': 0.5178723931312561}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'orrendamente', 'angoscia')
data2 = compare_cos(periods, models, 'orrendamente', 'atterrire')
data3 = compare_cos(periods, models, 'orrendamente', 'panico')
data4 = compare_cos(periods, models, 'orrendamente', 'paura')
data5 = compare_cos(periods, models, 'orrendamente', 'raccapricciare')
data6 = compare_cos(periods, models, 'orrendamente', 'schifo')
data7 = compare_cos(periods, models, 'orrendamente', 'sgomentare')
data8 = compare_cos(periods, models, 'orrendamente', 'sgomento')
data9 = compare_cos(periods, models, 'orrendamente', 'spaventare')
data10 = compare_cos(periods, models, 'orrendamente', 'spavento')
data11 = compare_cos(periods, models, 'orrendamente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### orribilmente

# %%
compare_words(periods, models, 'orribilmente')
# Out:
#                          1700-1750                         1751-1800  \
# 0   (naufrago, 0.9504192471504211)    (fiaccola, 0.9424194693565369)
# 1  (aquilonar, 0.9500489234924316)       (solco, 0.9404131174087524)
# 2     (turbin, 0.9485859274864197)    (rimbombo, 0.9333844184875488)
# 3       (atri, 0.9463469386100769)      (baleno, 0.9330147504806519)
# 4   (rabbioso, 0.9440560340881348)     (palpebra, 0.932839572429657)
# 5  (barchetta, 0.9438682794570923)      (lacero, 0.9290263056755066)
# 6    (corcira, 0.9437447190284729)        (teso, 0.9287362098693848)
# 7   (grandine, 0.9434891939163208)  (ricomporre, 0.9264546632766724)
# 8     (fremer, 0.9430516958236694)      (gigante, 0.925868570804596)
# 9    (balzare, 0.9414729475975037)     (antenna, 0.9243747591972351)
#
#                          1801-1825                         1826-1850  \
# 0    (fremito, 0.9608254432678223)       (rotto, 0.8770731091499329)
# ...

# %%
compare_cos(periods, models, 'orribilmente', 'molto')
# Out:
# {'1700-1750': 0.3091629445552826,
#  '1751-1800': 0.3101200759410858,
#  '1801-1825': 0.4411614239215851,
#  '1826-1850': 0.2842884659767151,
#  '1851-1875': 0.39008718729019165,
#  '1876-1900': 0.3577001094818115,
#  '1901-1925': 0.3138675093650818,
#  '1926-1950': 0.3542953431606293,
#  '1951-1975': 0.4281275272369385,
#  '1976-2000': 0.3166767656803131,
#  '2001-2010': 0.2748628854751587,
#  '2011-2016': 0.2567712962627411,
#  '2017-2021': 0.26867595314979553}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'orribilmente', 'molto')
x_indexes = np.arange(len(data))
plt.ylim(0, 1)
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.plot(x_indexes, data.values(), label='orribilmente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'orribilmente', 'angoscia')
# Out:
# {'1700-1750': 0.6775257587432861,
#  '1751-1800': 0.6526476740837097,
#  '1801-1825': 0.756550133228302,
#  '1826-1850': 0.5091772675514221,
#  '1851-1875': 0.5037312507629395,
#  '1876-1900': 0.26265451312065125,
#  '1901-1925': 0.3500674068927765,
#  '1926-1950': 0.4607588052749634,
#  '1951-1975': 0.6481180191040039,
#  '1976-2000': 0.29408514499664307,
#  '2001-2010': 0.4224376380443573,
#  '2011-2016': 0.5147544145584106,
#  '2017-2021': 0.4375065267086029}

# %%
compare_cos(periods, models, 'orribilmente', 'atterrire')
# Out:
# {'1700-1750': 0.44536176323890686,
#  '1751-1800': 0.6759058237075806,
#  '1801-1825': 0.8321405053138733,
#  '1826-1850': 0.40462392568588257,
#  '1851-1875': 0.5092520713806152,
#  '1876-1900': 0.3349989056587219,
#  '1901-1925': 0.42129626870155334,
#  '1926-1950': 0.4973081648349762,
#  '1951-1975': 0.9003105163574219,
#  '1976-2000': 0.4950294494628906,
#  '2001-2010': 0.623297393321991,
#  '2011-2016': 0.6074174046516418,
#  '2017-2021': 0.6416321396827698}

# %%
compare_cos(periods, models, 'orribilmente', 'panico')
# Out:
# {'1700-1750': 0.7224657535552979,
#  '1751-1800': 0.7668809294700623,
#  '1801-1825': 0.8091769218444824,
#  '1826-1850': 0.5990893840789795,
#  '1851-1875': 0.5590223670005798,
#  '1876-1900': 0.24652858078479767,
#  '1901-1925': 0.22150033712387085,
#  '1926-1950': 0.5105282068252563,
#  '1951-1975': 0.7525412440299988,
#  '1976-2000': 0.25605055689811707,
#  '2001-2010': 0.2663910984992981,
#  '2011-2016': 0.23745176196098328,
#  '2017-2021': 0.24832843244075775}

# %%
compare_cos(periods, models, 'orribilmente', 'paura')
# Out:
# {'1700-1750': 0.3860761523246765,
#  '1751-1800': 0.48433151841163635,
#  '1801-1825': 0.6482672691345215,
#  '1826-1850': 0.36004582047462463,
#  '1851-1875': 0.4376258850097656,
#  '1876-1900': 0.24780000746250153,
#  '1901-1925': 0.39929166436195374,
#  '1926-1950': 0.35810038447380066,
#  '1951-1975': 0.7028092741966248,
#  '1976-2000': 0.20253923535346985,
#  '2001-2010': 0.3376085162162781,
#  '2011-2016': 0.3350672423839569,
#  '2017-2021': 0.3166216313838959}

# %%
compare_cos(periods, models, 'orribilmente', 'raccapricciare')
# Out:
# {'1700-1750': 0.7184498310089111,
#  '1751-1800': 0.7924261093139648,
#  '1801-1825': 0.8578097820281982,
#  '1826-1850': 0.44544392824172974,
#  '1851-1875': 0.6818459630012512,
#  '1876-1900': 0.44149747490882874,
#  '1901-1925': 0.5256986618041992,
#  '1926-1950': 0.6990885734558105,
#  '1951-1975': 0.8544718027114868,
#  '1976-2000': 0.566688060760498,
#  '2001-2010': 0.6211243867874146,
#  '2011-2016': 0.6639537215232849,
#  '2017-2021': 0.6059054136276245}

# %%
compare_cos(periods, models, 'orribilmente', 'schifo')
# Out:
# {'1700-1750': 0.8344934582710266,
#  '1751-1800': 0.6026334166526794,
#  '1801-1825': 0.762916624546051,
#  '1826-1850': 0.5857475996017456,
#  '1851-1875': 0.5703420042991638,
#  '1876-1900': 0.32615119218826294,
#  '1901-1925': 0.5976765751838684,
#  '1926-1950': 0.397243857383728,
#  '1951-1975': 0.8703158497810364,
#  '1976-2000': 0.2871555984020233,
#  '2001-2010': 0.37589791417121887,
#  '2011-2016': 0.4237750172615051,
#  '2017-2021': 0.3639373481273651}

# %%
compare_cos(periods, models, 'orribilmente', 'sgomentare')
# Out:
# {'1700-1750': 0.6202885508537292,
#  '1751-1800': 0.6359579563140869,
#  '1801-1825': 0.7650594115257263,
#  '1826-1850': 0.4471047818660736,
#  '1851-1875': 0.47044116258621216,
#  '1876-1900': 0.3362947702407837,
#  '1901-1925': 0.4665096402168274,
#  '1926-1950': 0.5407294034957886,
#  '1951-1975': 0.8940129280090332,
#  '1976-2000': 0.3774036765098572,
#  '2001-2010': 0.6203123331069946,
#  '2011-2016': 0.6369656324386597,
#  '2017-2021': 0.5940209627151489}

# %%
compare_cos(periods, models, 'orribilmente', 'sgomento')
# Out:
# {'1700-1750': 0.86506187915802,
#  '1751-1800': 0.7291439771652222,
#  '1801-1825': 0.8370033502578735,
#  '1826-1850': 0.591699481010437,
#  '1851-1875': 0.49473774433135986,
#  '1876-1900': 0.24333567917346954,
#  '1901-1925': 0.3101899027824402,
#  '1926-1950': 0.46187523007392883,
#  '1951-1975': 0.714858889579773,
#  '1976-2000': 0.29725950956344604,
#  '2001-2010': 0.4152364134788513,
#  '2011-2016': 0.44624418020248413,
#  '2017-2021': 0.4317144751548767}

# %%
compare_cos(periods, models, 'orribilmente', 'spaventare')
# Out:
# {'1700-1750': 0.6082438826560974,
#  '1751-1800': 0.548275887966156,
#  '1801-1825': 0.6362379193305969,
#  '1826-1850': 0.3304610848426819,
#  '1851-1875': 0.46343207359313965,
#  '1876-1900': 0.23725269734859467,
#  '1901-1925': 0.3652247488498688,
#  '1926-1950': 0.44847360253334045,
#  '1951-1975': 0.8661051988601685,
#  '1976-2000': 0.19054703414440155,
#  '2001-2010': 0.4640766978263855,
#  '2011-2016': 0.4775139093399048,
#  '2017-2021': 0.42302536964416504}

# %%
compare_cos(periods, models, 'orribilmente', 'spavento')
# Out:
# {'1700-1750': 0.5060991048812866,
#  '1751-1800': 0.47711604833602905,
#  '1801-1825': 0.7701415419578552,
#  '1826-1850': 0.3833983242511749,
#  '1851-1875': 0.5209761261940002,
#  '1876-1900': 0.29026103019714355,
#  '1901-1925': 0.3226575553417206,
#  '1926-1950': 0.4964294731616974,
#  '1951-1975': 0.851290225982666,
#  '1976-2000': 0.3842625916004181,
#  '2001-2010': 0.5209811925888062,
#  '2011-2016': 0.5385676622390747,
#  '2017-2021': 0.47026073932647705}

# %%
compare_cos(periods, models, 'orribilmente', 'terrore')
# Out:
# {'1700-1750': 0.4443051815032959,
#  '1751-1800': 0.4148385226726532,
#  '1801-1825': 0.6086497902870178,
#  '1826-1850': 0.330366313457489,
#  '1851-1875': 0.45640429854393005,
#  '1876-1900': 0.23587001860141754,
#  '1901-1925': 0.2763337790966034,
#  '1926-1950': 0.4868151545524597,
#  '1951-1975': 0.7146657109260559,
#  '1976-2000': 0.3259214460849762,
#  '2001-2010': 0.4565199017524719,
#  '2011-2016': 0.37046754360198975,
#  '2017-2021': 0.4983779191970825}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'orribilmente', 'angoscia')
data2 = compare_cos(periods, models, 'orribilmente', 'atterrire')
data3 = compare_cos(periods, models, 'orribilmente', 'panico')
data4 = compare_cos(periods, models, 'orribilmente', 'paura')
data5 = compare_cos(periods, models, 'orribilmente', 'raccapricciare')
data6 = compare_cos(periods, models, 'orribilmente', 'schifo')
data7 = compare_cos(periods, models, 'orribilmente', 'sgomentare')
data8 = compare_cos(periods, models, 'orribilmente', 'sgomento')
data9 = compare_cos(periods, models, 'orribilmente', 'spaventare')
data10 = compare_cos(periods, models, 'orribilmente', 'spavento')
data11 = compare_cos(periods, models, 'orribilmente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### spaventosamente

# %%
compare_words(periods, models, 'spaventosamente')
# Out:
#                            1700-1750     1751-1800  \
# 0   (pestilenza, 0.9437798261642456)  not in vocab
# 1     (pozzuoli, 0.9359466433525085)  not in vocab
# 2     (eruzione, 0.9298276305198669)  not in vocab
# 3   (arcipelago, 0.9241703748703003)  not in vocab
# 4     (allagare, 0.9190033078193665)  not in vocab
# 5       (peloro, 0.9123673439025879)  not in vocab
# 6    (millesimo, 0.9122161269187927)  not in vocab
# 7  (riempierono, 0.9106054902076721)  not in vocab
# 8   (restaurare, 0.9098500609397888)  not in vocab
# 9     (ercolano, 0.9088594913482666)  not in vocab
#
#                         1801-1825                        1826-1850  \
# 0     (calan, 0.9924725890159607)    (bisognò, 0.9822773337364197)
# 1  (sulfureo, 0.9924605488777161)     (stecco, 0.9793540835380554)
# 2  (simoenta, 0.9920250177383423)    (prestar, 0.9791129231452942)
# 3     (guatò, 0.9919813871383667)     (tebane, 0.9787699580192566)
# ...

# %%
compare_cos(periods, models, 'spaventosamente', 'molto')
# Out:
# {'1700-1750': 0.44084325432777405,
#  '1801-1825': 0.4735126495361328,
#  '1826-1850': 0.4892875850200653,
#  '1851-1875': 0.43606629967689514,
#  '1876-1900': 0.4406340718269348,
#  '1901-1925': 0.34028327465057373,
#  '1926-1950': 0.3677822947502136,
#  '1951-1975': 0.511094868183136,
#  '1976-2000': 0.5444455742835999,
#  '2001-2010': 0.44722554087638855,
#  '2011-2016': 0.43512263894081116,
#  '2017-2021': 0.46277186274528503}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'spaventosamente', 'molto')
x_indexes = np.arange(len(data))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)
plt.plot(x_indexes, data.values(), label='spaventosamente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'spaventosamente', 'angoscia')
# Out:
# {'1700-1750': 0.5733606219291687,
#  '1801-1825': 0.62248694896698,
#  '1826-1850': 0.5269446969032288,
#  '1851-1875': 0.33557671308517456,
#  '1876-1900': 0.4891739785671234,
#  '1901-1925': 0.4082615077495575,
#  '1926-1950': 0.5212481021881104,
#  '1951-1975': 0.6840718984603882,
#  '1976-2000': 0.3978315591812134,
#  '2001-2010': 0.44523289799690247,
#  '2011-2016': 0.45989835262298584,
#  '2017-2021': 0.4722834825515747}

# %%
compare_cos(periods, models, 'spaventosamente', 'atterrire')
# Out:
# {'1700-1750': 0.35994887351989746,
#  '1801-1825': 0.7052361965179443,
#  '1826-1850': 0.46505245566368103,
#  '1851-1875': 0.4293002188205719,
#  '1876-1900': 0.44869205355644226,
#  '1901-1925': 0.515894889831543,
#  '1926-1950': 0.5776894688606262,
#  '1951-1975': 0.8522999882698059,
#  '1976-2000': 0.5283389687538147,
#  '2001-2010': 0.5332536697387695,
#  '2011-2016': 0.49784213304519653,
#  '2017-2021': 0.5348379611968994}

# %%
compare_cos(periods, models, 'spaventosamente', 'panico')
# Out:
# {'1700-1750': 0.7097245454788208,
#  '1801-1825': 0.9105327129364014,
#  '1826-1850': 0.6128181219100952,
#  '1851-1875': 0.7227867245674133,
#  '1876-1900': 0.5118496417999268,
#  '1901-1925': 0.3594762980937958,
#  '1926-1950': 0.5909985303878784,
#  '1951-1975': 0.7584779262542725,
#  '1976-2000': 0.2667745351791382,
#  '2001-2010': 0.2926858365535736,
#  '2011-2016': 0.2906043231487274,
#  '2017-2021': 0.2665523588657379}

# %%
compare_cos(periods, models, 'spaventosamente', 'paura')
# Out:
# {'1700-1750': 0.3506915271282196,
#  '1801-1825': 0.5447911024093628,
#  '1826-1850': 0.44833844900131226,
#  '1851-1875': 0.4002924859523773,
#  '1876-1900': 0.3441299498081207,
#  '1901-1925': 0.3186452090740204,
#  '1926-1950': 0.4003862738609314,
#  '1951-1975': 0.6139293313026428,
#  '1976-2000': 0.2973931133747101,
#  '2001-2010': 0.3115657866001129,
#  '2011-2016': 0.3502185344696045,
#  '2017-2021': 0.3606433868408203}

# %%
compare_cos(periods, models, 'spaventosamente', 'raccapricciare')
# Out:
# {'1700-1750': 0.755922257900238,
#  '1801-1825': 0.9311848282814026,
#  '1826-1850': 0.7131147384643555,
#  '1851-1875': 0.6137036085128784,
#  '1876-1900': 0.45089128613471985,
#  '1901-1925': 0.5283752083778381,
#  '1926-1950': 0.7106257081031799,
#  '1951-1975': 0.8313732743263245,
#  '1976-2000': 0.5888980627059937,
#  '2001-2010': 0.5334807634353638,
#  '2011-2016': 0.6457402110099792,
#  '2017-2021': 0.5468221306800842}

# %%
compare_cos(periods, models, 'spaventosamente', 'schifo')
# Out:
# {'1700-1750': 0.7911115884780884,
#  '1801-1825': 0.9008580446243286,
#  '1826-1850': 0.7833980321884155,
#  '1851-1875': 0.6488212943077087,
#  '1876-1900': 0.40557581186294556,
#  '1901-1925': 0.5287867784500122,
#  '1926-1950': 0.37230733036994934,
#  '1951-1975': 0.8314575552940369,
#  '1976-2000': 0.35612308979034424,
#  '2001-2010': 0.3254302144050598,
#  '2011-2016': 0.3959178328514099,
#  '2017-2021': 0.36276334524154663}

# %%
compare_cos(periods, models, 'spaventosamente', 'sgomentare')
# Out:
# {'1700-1750': 0.5067335367202759,
#  '1801-1825': 0.8061122298240662,
#  '1826-1850': 0.610793948173523,
#  '1851-1875': 0.4583838880062103,
#  '1876-1900': 0.4129517674446106,
#  '1901-1925': 0.4828778803348541,
#  '1926-1950': 0.6799796223640442,
#  '1951-1975': 0.8337516784667969,
#  '1976-2000': 0.3995412290096283,
#  '2001-2010': 0.5252286791801453,
#  '2011-2016': 0.49150776863098145,
#  '2017-2021': 0.5374010801315308}

# %%
compare_cos(periods, models, 'spaventosamente', 'sgomento')
# Out:
# {'1700-1750': 0.7846255898475647,
#  '1801-1825': 0.9804750680923462,
#  '1826-1850': 0.7053772807121277,
#  '1851-1875': 0.5181905627250671,
#  '1876-1900': 0.4134654402732849,
#  '1901-1925': 0.428092360496521,
#  '1926-1950': 0.5352279543876648,
#  '1951-1975': 0.7179381847381592,
#  '1976-2000': 0.3245379328727722,
#  '2001-2010': 0.38248318433761597,
#  '2011-2016': 0.4196804165840149,
#  '2017-2021': 0.4390018880367279}

# %%
compare_cos(periods, models, 'spaventosamente', 'spaventare')
# Out:
# {'1700-1750': 0.48412907123565674,
#  '1801-1825': 0.5628448128700256,
#  '1826-1850': 0.4120328724384308,
#  '1851-1875': 0.3860175907611847,
#  '1876-1900': 0.2812144160270691,
#  '1901-1925': 0.28770944476127625,
#  '1926-1950': 0.48810839653015137,
#  '1951-1975': 0.7696931958198547,
#  '1976-2000': 0.3505798280239105,
#  '2001-2010': 0.4249161183834076,
#  '2011-2016': 0.48837342858314514,
#  '2017-2021': 0.39524146914482117}

# %%
compare_cos(periods, models, 'spaventosamente', 'spavento')
# Out:
# {'1700-1750': 0.44217899441719055,
#  '1801-1825': 0.6236159205436707,
#  '1826-1850': 0.40080446004867554,
#  '1851-1875': 0.35706669092178345,
#  '1876-1900': 0.36410462856292725,
#  '1901-1925': 0.4221026301383972,
#  '1926-1950': 0.5228299498558044,
#  '1951-1975': 0.7878637909889221,
#  '1976-2000': 0.40167903900146484,
#  '2001-2010': 0.45714908838272095,
#  '2011-2016': 0.44798967242240906,
#  '2017-2021': 0.4603498578071594}

# %%
compare_cos(periods, models, 'spaventosamente', 'terrore')
# Out:
# {'1700-1750': 0.4206647574901581,
#  '1801-1825': 0.5090236663818359,
#  '1826-1850': 0.31811538338661194,
#  '1851-1875': 0.31467729806900024,
#  '1876-1900': 0.3623744249343872,
#  '1901-1925': 0.4527977406978607,
#  '1926-1950': 0.5086216330528259,
#  '1951-1975': 0.680968701839447,
#  '1976-2000': 0.37882083654403687,
#  '2001-2010': 0.4595348834991455,
#  '2011-2016': 0.43574970960617065,
#  '2017-2021': 0.4947616755962372}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'spaventosamente', 'angoscia')
data2 = compare_cos(periods, models, 'spaventosamente', 'atterrire')
data3 = compare_cos(periods, models, 'spaventosamente', 'panico')
data4 = compare_cos(periods, models, 'spaventosamente', 'paura')
data5 = compare_cos(periods, models, 'spaventosamente', 'raccapricciare')
data6 = compare_cos(periods, models, 'spaventosamente', 'schifo')
data7 = compare_cos(periods, models, 'spaventosamente', 'sgomentare')
data8 = compare_cos(periods, models, 'spaventosamente', 'sgomento')
data9 = compare_cos(periods, models, 'spaventosamente', 'spaventare')
data10 = compare_cos(periods, models, 'spaventosamente', 'spavento')
data11 = compare_cos(periods, models, 'spaventosamente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### terribilmente

# %%
compare_words(periods, models, 'terribilmente')
# Out:
#                            1700-1750                         1751-1800  \
# 0       (impreso, 0.963127076625824)   (oblivione, 0.9085426926612854)
# 1       (chiaia, 0.9596320390701294)     (labieno, 0.9058508276939392)
# 2     (frascati, 0.9591440558433533)    (sinagoga, 0.9049323201179504)
# 3    (impadronì, 0.9586966037750244)     (patente, 0.9047799110412598)
# 4  (procederono, 0.9576830863952637)    (emiliano, 0.9040188193321228)
# 5    (cannonata, 0.9576508402824402)      (carizmo, 0.901065468788147)
# 6          (vag, 0.9566539525985718)      (czarina, 0.901039183139801)
# 7         (ronco, 0.956052303314209)       (winck, 0.9006773233413696)
# 8        (garda, 0.9560025930404663)   (pentapoli, 0.9004939198493958)
# 9      (guadare, 0.9548219442367554)  (irresoluto, 0.8998441100120544)
#
#                            1801-1825                           1826-1850  \
# 0  (crudelmente, 0.9596908688545227)     (pontificj, 0.8934215903282166)
# ...

# %%
compare_cos(periods, models, 'terribilmente', 'molto')
# Out:
# {'1700-1750': 0.43888163566589355,
#  '1751-1800': 0.5162028670310974,
#  '1801-1825': 0.6495211124420166,
#  '1826-1850': 0.4535045325756073,
#  '1851-1875': 0.4889950454235077,
#  '1876-1900': 0.36268508434295654,
#  '1901-1925': 0.4166601896286011,
#  '1926-1950': 0.39865511655807495,
#  '1951-1975': 0.5245971083641052,
#  '1976-2000': 0.4688042998313904,
#  '2001-2010': 0.41489702463150024,
#  '2011-2016': 0.384290486574173,
#  '2017-2021': 0.46509256958961487}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'terribilmente', 'molto')
x_indexes = np.arange(len(data))
plt.ylim(0, 1)
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.plot(x_indexes, data.values(), label='terribilmente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'terribilmente', 'angoscia')
# Out:
# {'1700-1750': 0.5076652765274048,
#  '1751-1800': 0.5590095520019531,
#  '1801-1825': 0.7462354898452759,
#  '1826-1850': 0.41197964549064636,
#  '1851-1875': 0.5059369802474976,
#  '1876-1900': 0.33573055267333984,
#  '1901-1925': 0.36207789182662964,
#  '1926-1950': 0.3696328401565552,
#  '1951-1975': 0.7759844660758972,
#  '1976-2000': 0.23484201729297638,
#  '2001-2010': 0.37688928842544556,
#  '2011-2016': 0.389581561088562,
#  '2017-2021': 0.4690931737422943}

# %%
compare_cos(periods, models, 'terribilmente', 'atterrire')
# Out:
# {'1700-1750': 0.4949624836444855,
#  '1751-1800': 0.7374706864356995,
#  '1801-1825': 0.7956297993659973,
#  '1826-1850': 0.5416379570960999,
#  '1851-1875': 0.517927885055542,
#  '1876-1900': 0.3711090683937073,
#  '1901-1925': 0.4971106946468353,
#  '1926-1950': 0.534453272819519,
#  '1951-1975': 0.7723864316940308,
#  '1976-2000': 0.4358291029930115,
#  '2001-2010': 0.4394492208957672,
#  '2011-2016': 0.4576357305049896,
#  '2017-2021': 0.5142281651496887}

# %%
compare_cos(periods, models, 'terribilmente', 'panico')
# Out:
# {'1700-1750': 0.8610864877700806,
#  '1751-1800': 0.8067318797111511,
#  '1801-1825': 0.924812376499176,
#  '1826-1850': 0.6764655709266663,
#  '1851-1875': 0.5419200658798218,
#  '1876-1900': 0.2658521234989166,
#  '1901-1925': 0.3879075050354004,
#  '1926-1950': 0.4916735887527466,
#  '1951-1975': 0.7982964515686035,
#  '1976-2000': 0.22959710657596588,
#  '2001-2010': 0.23431219160556793,
#  '2011-2016': 0.20325882732868195,
#  '2017-2021': 0.3291056752204895}

# %%
compare_cos(periods, models, 'terribilmente', 'paura')
# Out:
# {'1700-1750': 0.45162928104400635,
#  '1751-1800': 0.42528289556503296,
#  '1801-1825': 0.7060024738311768,
#  '1826-1850': 0.40821725130081177,
#  '1851-1875': 0.49447035789489746,
#  '1876-1900': 0.264418363571167,
#  '1901-1925': 0.3667071759700775,
#  '1926-1950': 0.4152086079120636,
#  '1951-1975': 0.7222781777381897,
#  '1976-2000': 0.1900331676006317,
#  '2001-2010': 0.28666767477989197,
#  '2011-2016': 0.2856479585170746,
#  '2017-2021': 0.3869343101978302}

# %%
compare_cos(periods, models, 'terribilmente', 'raccapricciare')
# Out:
# {'1700-1750': 0.8120443224906921,
#  '1751-1800': 0.835160493850708,
#  '1801-1825': 0.9115723371505737,
#  '1826-1850': 0.613634467124939,
#  '1851-1875': 0.7014186978340149,
#  '1876-1900': 0.4997970163822174,
#  '1901-1925': 0.536026120185852,
#  '1926-1950': 0.6432052254676819,
#  '1951-1975': 0.7220354080200195,
#  '1976-2000': 0.3744029104709625,
#  '2001-2010': 0.4746500551700592,
#  '2011-2016': 0.5536632537841797,
#  '2017-2021': 0.5693029165267944}

# %%
compare_cos(periods, models, 'terribilmente', 'schifo')
# Out:
# {'1700-1750': 0.8602995872497559,
#  '1751-1800': 0.7105746269226074,
#  '1801-1825': 0.924614429473877,
#  '1826-1850': 0.8138498067855835,
#  '1851-1875': 0.5737400650978088,
#  '1876-1900': 0.2048882395029068,
#  '1901-1925': 0.4598083794116974,
#  '1926-1950': 0.39070820808410645,
#  '1951-1975': 0.9083440899848938,
#  '1976-2000': 0.22838164865970612,
#  '2001-2010': 0.3512997031211853,
#  '2011-2016': 0.3754264712333679,
#  '2017-2021': 0.38824281096458435}

# %%
compare_cos(periods, models, 'terribilmente', 'sgomentare')
# Out:
# {'1700-1750': 0.5968565940856934,
#  '1751-1800': 0.698954164981842,
#  '1801-1825': 0.906008780002594,
#  '1826-1850': 0.7122296690940857,
#  '1851-1875': 0.4853978455066681,
#  '1876-1900': 0.4471653401851654,
#  '1901-1925': 0.5885913968086243,
#  '1926-1950': 0.4919796586036682,
#  '1951-1975': 0.7264812588691711,
#  '1976-2000': 0.4002295136451721,
#  '2001-2010': 0.44752267003059387,
#  '2011-2016': 0.5685674548149109,
#  '2017-2021': 0.5840812921524048}

# %%
compare_cos(periods, models, 'terribilmente', 'sgomento')
# Out:
# {'1700-1750': 0.8359837532043457,
#  '1751-1800': 0.8320161700248718,
#  '1801-1825': 0.8668138384819031,
#  '1826-1850': 0.616936981678009,
#  '1851-1875': 0.6419929265975952,
#  '1876-1900': 0.33754023909568787,
#  '1901-1925': 0.3934759199619293,
#  '1926-1950': 0.41272661089897156,
#  '1951-1975': 0.8602285385131836,
#  '1976-2000': 0.18589769303798676,
#  '2001-2010': 0.28955012559890747,
#  '2011-2016': 0.3781525790691376,
#  '2017-2021': 0.4135493040084839}

# %%
compare_cos(periods, models, 'terribilmente', 'spaventare')
# Out:
# {'1700-1750': 0.6162282228469849,
#  '1751-1800': 0.5752805471420288,
#  '1801-1825': 0.7367022037506104,
#  '1826-1850': 0.46019643545150757,
#  '1851-1875': 0.4571564495563507,
#  '1876-1900': 0.3074404001235962,
#  '1901-1925': 0.3888763189315796,
#  '1926-1950': 0.5044485926628113,
#  '1951-1975': 0.8274402022361755,
#  '1976-2000': 0.4089391529560089,
#  '2001-2010': 0.37267205119132996,
#  '2011-2016': 0.4343801736831665,
#  '2017-2021': 0.4989093244075775}

# %%
compare_cos(periods, models, 'terribilmente', 'spavento')
# Out:
# {'1700-1750': 0.5249961018562317,
#  '1751-1800': 0.5209127068519592,
#  '1801-1825': 0.7516695261001587,
#  '1826-1850': 0.3676425516605377,
#  '1851-1875': 0.5027915835380554,
#  '1876-1900': 0.33988338708877563,
#  '1901-1925': 0.39118650555610657,
#  '1926-1950': 0.5353609919548035,
#  '1951-1975': 0.8298356533050537,
#  '1976-2000': 0.277220219373703,
#  '2001-2010': 0.3218809962272644,
#  '2011-2016': 0.3691807985305786,
#  '2017-2021': 0.4556419849395752}

# %%
compare_cos(periods, models, 'terribilmente', 'terrore')
# Out:
# {'1700-1750': 0.4941180944442749,
#  '1751-1800': 0.4143849313259125,
#  '1801-1825': 0.6376410126686096,
#  '1826-1850': 0.3347393572330475,
#  '1851-1875': 0.43503323197364807,
#  '1876-1900': 0.34175825119018555,
#  '1901-1925': 0.45183032751083374,
#  '1926-1950': 0.4433046281337738,
#  '1951-1975': 0.6877734661102295,
#  '1976-2000': 0.15713749825954437,
#  '2001-2010': 0.30086156725883484,
#  '2011-2016': 0.290574848651886,
#  '2017-2021': 0.41084668040275574}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'terribilmente', 'angoscia')
data2 = compare_cos(periods, models, 'terribilmente', 'atterrire')
data3 = compare_cos(periods, models, 'terribilmente', 'panico')
data4 = compare_cos(periods, models, 'terribilmente', 'paura')
data5 = compare_cos(periods, models, 'terribilmente', 'raccapricciare')
data6 = compare_cos(periods, models, 'terribilmente', 'schifo')
data7 = compare_cos(periods, models, 'terribilmente', 'sgomentare')
data8 = compare_cos(periods, models, 'terribilmente', 'sgomento')
data9 = compare_cos(periods, models, 'terribilmente', 'spaventare')
data10 = compare_cos(periods, models, 'terribilmente', 'spavento')
data11 = compare_cos(periods, models, 'terribilmente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### tremendamente

# %%
compare_words(periods, models, 'tremendamente')
# Out:
#       1700-1750     1751-1800                         1801-1825  \
# 0  not in vocab  not in vocab     (ubbidir, 0.9896525740623474)
# 1  not in vocab  not in vocab        (lidi, 0.9894166588783264)
# 2  not in vocab  not in vocab     (meteore, 0.9889436960220337)
# 3  not in vocab  not in vocab   (gorgoglia, 0.9887739419937134)
# 4  not in vocab  not in vocab  (appresenta, 0.9878779649734497)
# 5  not in vocab  not in vocab     (contien, 0.9878342747688293)
# 6  not in vocab  not in vocab       (terge, 0.9871344566345215)
# 7  not in vocab  not in vocab  (collicello, 0.9870616793632507)
# 8  not in vocab  not in vocab  (squarciate, 0.9869048595428467)
# 9  not in vocab  not in vocab       (istmo, 0.9867355227470398)
#
#                                1826-1850                          1851-1875  \
# 0        (invaghite, 0.9667903184890747)   (comprimere, 0.9011471271514893)
# 1        (rammentalo, 0.961743950843811)   (spasimante, 0.8748427629470825)
# ...

# %%
compare_cos(periods, models, 'tremendamente', 'molto')
# Out:
# {'1801-1825': 0.5257567167282104,
#  '1826-1850': 0.525058388710022,
#  '1851-1875': 0.45880383253097534,
#  '1876-1900': 0.4587910771369934,
#  '1901-1925': 0.531973659992218,
#  '1926-1950': 0.427776575088501,
#  '1951-1975': 0.5660892128944397,
#  '1976-2000': 0.5174748301506042,
#  '2001-2010': 0.4643295109272003,
#  '2011-2016': 0.4398612380027771,
#  '2017-2021': 0.44553428888320923}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'tremendamente', 'molto')
x_indexes = np.arange(len(data))
plt.ylim(0, 1)
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.plot(x_indexes, data.values(), label='tremendamente-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'tremendamente', 'angoscia')
# Out:
# {'1801-1825': 0.584425151348114,
#  '1826-1850': 0.5375969409942627,
#  '1851-1875': 0.5844604969024658,
#  '1876-1900': 0.5202980637550354,
#  '1901-1925': 0.3846926689147949,
#  '1926-1950': 0.46753570437431335,
#  '1951-1975': 0.6107752919197083,
#  '1976-2000': 0.26331615447998047,
#  '2001-2010': 0.39570751786231995,
#  '2011-2016': 0.3778495192527771,
#  '2017-2021': 0.3999887704849243}

# %%
compare_cos(periods, models, 'tremendamente', 'atterrire')
# Out:
# {'1801-1825': 0.6522600650787354,
#  '1826-1850': 0.4613969326019287,
#  '1851-1875': 0.4843486547470093,
#  '1876-1900': 0.4299685060977936,
#  '1901-1925': 0.43932515382766724,
#  '1926-1950': 0.5941413640975952,
#  '1951-1975': 0.8309264183044434,
#  '1976-2000': 0.43448662757873535,
#  '2001-2010': 0.4673857092857361,
#  '2011-2016': 0.3611554205417633,
#  '2017-2021': 0.4313276708126068}

# %%
compare_cos(periods, models, 'tremendamente', 'panico')
# Out:
# {'1801-1825': 0.8921129107475281,
#  '1826-1850': 0.6227679252624512,
#  '1851-1875': 0.4807550311088562,
#  '1876-1900': 0.34755057096481323,
#  '1901-1925': 0.5206053256988525,
#  '1926-1950': 0.7315978407859802,
#  '1951-1975': 0.7774893045425415,
#  '1976-2000': 0.2948015630245209,
#  '2001-2010': 0.24887560307979584,
#  '2011-2016': 0.21189400553703308,
#  '2017-2021': 0.2639256715774536}

# %%
compare_cos(periods, models, 'tremendamente', 'paura')
# Out:
# {'1801-1825': 0.5217462778091431,
#  '1826-1850': 0.44897639751434326,
#  '1851-1875': 0.4010869264602661,
#  '1876-1900': 0.3101044297218323,
#  '1901-1925': 0.30885443091392517,
#  '1926-1950': 0.41892489790916443,
#  '1951-1975': 0.5139546394348145,
#  '1976-2000': 0.2771511375904083,
#  '2001-2010': 0.31062811613082886,
#  '2011-2016': 0.272462397813797,
#  '2017-2021': 0.3410250246524811}

# %%
compare_cos(periods, models, 'tremendamente', 'raccapricciare')
# Out:
# {'1801-1825': 0.9019944667816162,
#  '1826-1850': 0.7493635416030884,
#  '1851-1875': 0.7165013551712036,
#  '1876-1900': 0.6047235131263733,
#  '1901-1925': 0.8292511701583862,
#  '1926-1950': 0.8406659960746765,
#  '1951-1975': 0.9289780259132385,
#  '1976-2000': 0.4244847297668457,
#  '2001-2010': 0.5167545080184937,
#  '2011-2016': 0.5215359330177307,
#  '2017-2021': 0.47935691475868225}

# %%
compare_cos(periods, models, 'tremendamente', 'schifo')
# Out:
# {'1801-1825': 0.9154459238052368,
#  '1826-1850': 0.7935566902160645,
#  '1851-1875': 0.582960844039917,
#  '1876-1900': 0.23736438155174255,
#  '1901-1925': 0.6561486124992371,
#  '1926-1950': 0.5865163803100586,
#  '1951-1975': 0.7595158219337463,
#  '1976-2000': 0.31464940309524536,
#  '2001-2010': 0.37397462129592896,
#  '2011-2016': 0.41709569096565247,
#  '2017-2021': 0.3814060688018799}

# %%
compare_cos(periods, models, 'tremendamente', 'sgomentare')
# Out:
# {'1801-1825': 0.818503201007843,
#  '1826-1850': 0.6106842756271362,
#  '1851-1875': 0.46188274025917053,
#  '1876-1900': 0.4818965792655945,
#  '1901-1925': 0.561430811882019,
#  '1926-1950': 0.6632668972015381,
#  '1951-1975': 0.824472188949585,
#  '1976-2000': 0.3638908565044403,
#  '2001-2010': 0.5000708699226379,
#  '2011-2016': 0.4861842393875122,
#  '2017-2021': 0.41781583428382874}

# %%
compare_cos(periods, models, 'tremendamente', 'sgomento')
# Out:
# {'1801-1825': 0.9534716606140137,
#  '1826-1850': 0.7094225883483887,
#  '1851-1875': 0.531311571598053,
#  '1876-1900': 0.41361287236213684,
#  '1901-1925': 0.47731727361679077,
#  '1926-1950': 0.6083856225013733,
#  '1951-1975': 0.7698363065719604,
#  '1976-2000': 0.20673564076423645,
#  '2001-2010': 0.3291250169277191,
#  '2011-2016': 0.294241726398468,
#  '2017-2021': 0.3050508201122284}

# %%
compare_cos(periods, models, 'tremendamente', 'spaventare')
# Out:
# {'1801-1825': 0.5345690250396729,
#  '1826-1850': 0.40235358476638794,
#  '1851-1875': 0.3786979913711548,
#  '1876-1900': 0.35292068123817444,
#  '1901-1925': 0.3426755368709564,
#  '1926-1950': 0.525394082069397,
#  '1951-1975': 0.5931102633476257,
#  '1976-2000': 0.3650919198989868,
#  '2001-2010': 0.4323979616165161,
#  '2011-2016': 0.38901859521865845,
#  '2017-2021': 0.4460482895374298}

# %%
compare_cos(periods, models, 'tremendamente', 'spavento')
# Out:
# {'1801-1825': 0.5849622488021851,
#  '1826-1850': 0.3666068911552429,
#  '1851-1875': 0.40699636936187744,
#  '1876-1900': 0.34253430366516113,
#  '1901-1925': 0.3674871325492859,
#  '1926-1950': 0.5314953327178955,
#  '1951-1975': 0.6286476850509644,
#  '1976-2000': 0.36054402589797974,
#  '2001-2010': 0.36783549189567566,
#  '2011-2016': 0.3194960951805115,
#  '2017-2021': 0.40417763590812683}

# %%
compare_cos(periods, models, 'tremendamente', 'terrore')
# Out:
# {'1801-1825': 0.47935107350349426,
#  '1826-1850': 0.321590781211853,
#  '1851-1875': 0.43054208159446716,
#  '1876-1900': 0.2666357159614563,
#  '1901-1925': 0.29743361473083496,
#  '1926-1950': 0.39896392822265625,
#  '1951-1975': 0.5667640566825867,
#  '1976-2000': 0.24193108081817627,
#  '2001-2010': 0.3328552842140198,
#  '2011-2016': 0.2437327355146408,
#  '2017-2021': 0.32123932242393494}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'tremendamente', 'angoscia')
data2 = compare_cos(periods, models, 'tremendamente', 'atterrire')
data3 = compare_cos(periods, models, 'tremendamente', 'panico')
data4 = compare_cos(periods, models, 'tremendamente', 'paura')
data5 = compare_cos(periods, models, 'tremendamente', 'raccapricciare')
data6 = compare_cos(periods, models, 'tremendamente', 'schifo')
data7 = compare_cos(periods, models, 'tremendamente', 'sgomentare')
data8 = compare_cos(periods, models, 'tremendamente', 'sgomento')
data9 = compare_cos(periods, models, 'tremendamente', 'spaventare')
data10 = compare_cos(periods, models, 'tremendamente', 'spavento')
data11 = compare_cos(periods, models, 'tremendamente', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### domani

# %%
compare_words(periods, models, 'domani')
# Out:
#                            1700-1750                        1751-1800  \
# 0     (bisbetico, 0.825036883354187)       (ieri, 0.8945176601409912)
# 1    (destinato, 0.7618731260299683)  (cameriera, 0.8775724172592163)
# 2         (sodo, 0.7501420378684998)   (teresina, 0.8773589730262756)
# 3     (tradurre, 0.7491852045059204)    (stasera, 0.8725716471672058)
# 4  (metamorfosi, 0.7486744523048401)     (lunedì, 0.8722690343856812)
# 5    (favellare, 0.7443892359733582)       (sera, 0.8587257266044617)
# 6        (fatta, 0.7429686784744263)     (martedì, 0.857754647731781)
# 7        (giust, 0.7413404583930969)       (tita, 0.8498836159706116)
# 8    (differire, 0.7411137223243713)    (giocare, 0.8455948829650879)
# 9  (ventiquattr, 0.7391349077224731)  (mercoledì, 0.8442691564559937)
#
#                           1801-1825                        1826-1850  \
# 0      (lunedì, 0.8105335831642151)     (dimani, 0.7996277213096619)
# ...

# %%
compare_cos(periods, models, 'domani', 'molto')
# Out:
# {'1700-1750': 0.36290526390075684,
#  '1751-1800': 0.27568188309669495,
#  '1801-1825': 0.3481431305408478,
#  '1826-1850': 0.2025579810142517,
#  '1851-1875': 0.3193894326686859,
#  '1876-1900': 0.25614115595817566,
#  '1901-1925': 0.21404960751533508,
#  '1926-1950': 0.21591588854789734,
#  '1951-1975': 0.4805401861667633,
#  '1976-2000': 0.2736136317253113,
#  '2001-2010': 0.2429431676864624,
#  '2011-2016': 0.21374215185642242,
#  '2017-2021': 0.24339652061462402}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'domani', 'molto')
x_indexes = np.arange(len(data))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)
plt.plot(x_indexes, data.values(), label='domani-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'domani', 'angoscia')
# Out:
# {'1700-1750': 0.49173200130462646,
#  '1751-1800': 0.423974871635437,
#  '1801-1825': 0.4509022533893585,
#  '1826-1850': 0.3892075717449188,
#  '1851-1875': 0.2687181532382965,
#  '1876-1900': 0.17520678043365479,
#  '1901-1925': 0.2869718670845032,
#  '1926-1950': 0.2572387456893921,
#  '1951-1975': 0.31407055258750916,
#  '1976-2000': 0.2154306173324585,
#  '2001-2010': 0.19669711589813232,
#  '2011-2016': 0.20449267327785492,
#  '2017-2021': 0.16950638592243195}

# %%
compare_cos(periods, models, 'domani', 'atterrire')
# Out:
# {'1700-1750': 0.34108394384384155,
#  '1751-1800': 0.34732818603515625,
#  '1801-1825': 0.40479204058647156,
#  '1826-1850': 0.10760784894227982,
#  '1851-1875': 0.27306699752807617,
#  '1876-1900': 0.09405388683080673,
#  '1901-1925': 0.16645443439483643,
#  '1926-1950': 0.1549699306488037,
#  '1951-1975': 0.5061020851135254,
#  '1976-2000': 0.2168092131614685,
#  '2001-2010': 0.21641843020915985,
#  '2011-2016': 0.193537175655365,
#  '2017-2021': 0.14762230217456818}

# %%
compare_cos(periods, models, 'domani', 'panico')
# Out:
# {'1700-1750': 0.4627555012702942,
#  '1751-1800': 0.46056580543518066,
#  '1801-1825': 0.46582356095314026,
#  '1826-1850': 0.19055263698101044,
#  '1851-1875': 0.2501959502696991,
#  '1876-1900': 0.1865178346633911,
#  '1901-1925': 0.18159911036491394,
#  '1926-1950': 0.2461138218641281,
#  '1951-1975': 0.520955502986908,
#  '1976-2000': 0.17606940865516663,
#  '2001-2010': 0.17609146237373352,
#  '2011-2016': 0.17928853631019592,
#  '2017-2021': 0.12487857043743134}

# %%
compare_cos(periods, models, 'domani', 'paura')
# Out:
# {'1700-1750': 0.23467281460762024,
#  '1751-1800': 0.5004887580871582,
#  '1801-1825': 0.49379763007164,
#  '1826-1850': 0.24102424085140228,
#  '1851-1875': 0.28416433930397034,
#  '1876-1900': 0.23065613210201263,
#  '1901-1925': 0.19499346613883972,
#  '1926-1950': 0.25227153301239014,
#  '1951-1975': 0.421371728181839,
#  '1976-2000': 0.21773558855056763,
#  '2001-2010': 0.17404037714004517,
#  '2011-2016': 0.21638451516628265,
#  '2017-2021': 0.24764218926429749}

# %%
compare_cos(periods, models, 'domani', 'raccapricciare')
# Out:
# {'1700-1750': 0.6450726389884949,
#  '1751-1800': 0.5601632595062256,
#  '1801-1825': 0.513892412185669,
#  '1826-1850': 0.40814051032066345,
#  '1851-1875': 0.31314143538475037,
#  '1876-1900': 0.2920481860637665,
#  '1901-1925': 0.27095136046409607,
#  '1926-1950': 0.27172672748565674,
#  '1951-1975': 0.5641409158706665,
#  '1976-2000': 0.28716859221458435,
#  '2001-2010': 0.281367689371109,
#  '2011-2016': 0.19515587389469147,
#  '2017-2021': 0.1274159997701645}

# %%
compare_cos(periods, models, 'domani', 'schifo')
# Out:
# {'1700-1750': 0.5052534937858582,
#  '1751-1800': 0.3372284471988678,
#  '1801-1825': 0.4706713855266571,
#  '1826-1850': 0.33609890937805176,
#  '1851-1875': 0.320019006729126,
#  '1876-1900': 0.09685876220464706,
#  '1901-1925': 0.19046346843242645,
#  '1926-1950': 0.062105923891067505,
#  '1951-1975': 0.5714931488037109,
#  '1976-2000': 0.2285122573375702,
#  '2001-2010': 0.23880039155483246,
#  '2011-2016': 0.18243177235126495,
#  '2017-2021': 0.1832476258277893}

# %%
compare_cos(periods, models, 'domani', 'sgomentare')
# Out:
# {'1700-1750': 0.4169408679008484,
#  '1751-1800': 0.37906259298324585,
#  '1801-1825': 0.5141503810882568,
#  '1826-1850': 0.27450788021087646,
#  '1851-1875': 0.3033486008644104,
#  '1876-1900': 0.21402911841869354,
#  '1901-1925': 0.24659085273742676,
#  '1926-1950': 0.2966533303260803,
#  '1951-1975': 0.4712181091308594,
#  '1976-2000': 0.2423756867647171,
#  '2001-2010': 0.1843899041414261,
#  '2011-2016': 0.1939728856086731,
#  '2017-2021': 0.1843075454235077}

# %%
compare_cos(periods, models, 'domani', 'sgomento')
# Out:
# {'1700-1750': 0.5252687335014343,
#  '1751-1800': 0.5148472785949707,
#  '1801-1825': 0.43960222601890564,
#  '1826-1850': 0.41462597250938416,
#  '1851-1875': 0.25759685039520264,
#  '1876-1900': 0.31319889426231384,
#  '1901-1925': 0.3070295751094818,
#  '1926-1950': 0.20438915491104126,
#  '1951-1975': 0.6092502474784851,
#  '1976-2000': 0.19038784503936768,
#  '2001-2010': 0.19253557920455933,
#  '2011-2016': 0.145000621676445,
#  '2017-2021': 0.16008304059505463}

# %%
compare_cos(periods, models, 'domani', 'spaventare')
# Out:
# {'1700-1750': 0.27556630969047546,
#  '1751-1800': 0.32235532999038696,
#  '1801-1825': 0.5382516980171204,
#  '1826-1850': 0.22978265583515167,
#  '1851-1875': 0.23454785346984863,
#  '1876-1900': 0.15250277519226074,
#  '1901-1925': 0.219155415892601,
#  '1926-1950': 0.31344887614250183,
#  '1951-1975': 0.5605877041816711,
#  '1976-2000': 0.271516889333725,
#  '2001-2010': 0.23393361270427704,
#  '2011-2016': 0.23795823752880096,
#  '2017-2021': 0.2300296276807785}

# %%
compare_cos(periods, models, 'domani', 'spavento')
# Out:
# {'1700-1750': 0.1781613677740097,
#  '1751-1800': 0.2632709741592407,
#  '1801-1825': 0.3700396418571472,
#  '1826-1850': 0.12847422063350677,
#  '1851-1875': 0.23666934669017792,
#  '1876-1900': 0.21797044575214386,
#  '1901-1925': 0.1505718231201172,
#  '1926-1950': 0.22254757583141327,
#  '1951-1975': 0.4448757469654083,
#  '1976-2000': 0.25181713700294495,
#  '2001-2010': 0.19617372751235962,
#  '2011-2016': 0.184978649020195,
#  '2017-2021': 0.17175287008285522}

# %%
compare_cos(periods, models, 'domani', 'terrore')
# Out:
# {'1700-1750': 0.21750377118587494,
#  '1751-1800': 0.1569390743970871,
#  '1801-1825': 0.3440025746822357,
#  '1826-1850': 0.040215156972408295,
#  '1851-1875': 0.2447572946548462,
#  '1876-1900': 0.17767632007598877,
#  '1901-1925': 0.24588711559772491,
#  '1926-1950': 0.18600383400917053,
#  '1951-1975': 0.33879175782203674,
#  '1976-2000': 0.1664227545261383,
#  '2001-2010': 0.19616053998470306,
#  '2011-2016': 0.18409252166748047,
#  '2017-2021': 0.13842491805553436}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'domani', 'angoscia')
data2 = compare_cos(periods, models, 'domani', 'atterrire')
data3 = compare_cos(periods, models, 'domani', 'panico')
data4 = compare_cos(periods, models, 'domani', 'paura')
data5 = compare_cos(periods, models, 'domani', 'raccapricciare')
data6 = compare_cos(periods, models, 'domani', 'schifo')
data7 = compare_cos(periods, models, 'domani', 'sgomentare')
data8 = compare_cos(periods, models, 'domani', 'sgomento')
data9 = compare_cos(periods, models, 'domani', 'spaventare')
data10 = compare_cos(periods, models, 'domani', 'spavento')
data11 = compare_cos(periods, models, 'domani', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()

# %% [markdown]
# ### spesso

# %%
compare_words(periods, models, 'spesso')
# Out:
#                               1700-1750                        1751-1800  \
# 0          (solere, 0.6161420941352844)     (radere, 0.6162957549095154)
# 1       (frequente, 0.5595386624336243)       (rado, 0.6008403301239014)
# 2         (sovente, 0.5450469851493835)   (talvolta, 0.5925845503807068)
# 3      (fastidioso, 0.5342600345611572)     (pagani, 0.5835213661193848)
# 4       (giudaismo, 0.5237780809402466)       (rare, 0.5832733511924744)
# 5     (frequentare, 0.5237205624580383)  (affettare, 0.5751301050186157)
# 6       (sedizione, 0.5164526104927063)   (politica, 0.5734770894050598)
# 7  (ordinariamente, 0.5152614116668701)   (traviare, 0.5733333230018616)
# 8        (saraceni, 0.5143526196479797)  (inesperto, 0.5731157064437866)
# 9       (scorreria, 0.5123974084854126)   (perorare, 0.5660426616668701)
#
#                             1801-1825                         1826-1850  \
# 0      (talvolta, 0.7980422973632812)    (talvolta, 0.5971521735191345)
# ...

# %%
compare_cos(periods, models, 'spesso', 'molto')
# Out:
# {'1700-1750': 0.37433022260665894,
#  '1751-1800': 0.36147555708885193,
#  '1801-1825': 0.5332525968551636,
#  '1826-1850': 0.3423668444156647,
#  '1851-1875': 0.33656615018844604,
#  '1876-1900': 0.3151383399963379,
#  '1901-1925': 0.3116817772388458,
#  '1926-1950': 0.341164231300354,
#  '1951-1975': 0.4326479136943817,
#  '1976-2000': 0.4034980535507202,
#  '2001-2010': 0.4389258921146393,
#  '2011-2016': 0.37646737694740295,
#  '2017-2021': 0.4039803445339203}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data = compare_cos(periods, models, 'spesso', 'molto')
x_indexes = np.arange(len(data))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)
plt.plot(x_indexes, data.values(), label='spesso-molto', marker='o', color='b')
plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), '--k')

plt.tight_layout()
plt.margins(0.05, 0.05)
#plt.legend(loc='upper right')

plt.show()

# %%
compare_cos(periods, models, 'spesso', 'angoscia')
# Out:
# {'1700-1750': 0.3155772089958191,
#  '1751-1800': 0.3247452974319458,
#  '1801-1825': 0.45530128479003906,
#  '1826-1850': 0.15767523646354675,
#  '1851-1875': 0.32956328988075256,
#  '1876-1900': 0.1920926570892334,
#  '1901-1925': 0.24936126172542572,
#  '1926-1950': 0.19403883814811707,
#  '1951-1975': 0.4590338170528412,
#  '1976-2000': 0.22609873116016388,
#  '2001-2010': 0.33738911151885986,
#  '2011-2016': 0.3684920072555542,
#  '2017-2021': 0.3446143567562103}

# %%
compare_cos(periods, models, 'spesso', 'atterrire')
# Out:
# {'1700-1750': 0.33143025636672974,
#  '1751-1800': 0.44290947914123535,
#  '1801-1825': 0.4933342933654785,
#  '1826-1850': 0.23986613750457764,
#  '1851-1875': 0.3222222328186035,
#  '1876-1900': 0.222686767578125,
#  '1901-1925': 0.205608069896698,
#  '1926-1950': 0.32915863394737244,
#  '1951-1975': 0.46725451946258545,
#  '1976-2000': 0.32983043789863586,
#  '2001-2010': 0.2912214398384094,
#  '2011-2016': 0.28434425592422485,
#  '2017-2021': 0.29456767439842224}

# %%
compare_cos(periods, models, 'spesso', 'panico')
# Out:
# {'1700-1750': 0.3750527501106262,
#  '1751-1800': 0.37497255206108093,
#  '1801-1825': 0.5589661598205566,
#  '1826-1850': 0.20817503333091736,
#  '1851-1875': 0.29709669947624207,
#  '1876-1900': 0.214557483792305,
#  '1901-1925': 0.16489602625370026,
#  '1926-1950': 0.324596107006073,
#  '1951-1975': 0.5711116194725037,
#  '1976-2000': 0.21871088445186615,
#  '2001-2010': 0.23161067068576813,
#  '2011-2016': 0.28473958373069763,
#  '2017-2021': 0.2919616103172302}

# %%
compare_cos(periods, models, 'spesso', 'paura')
# Out:
# {'1700-1750': 0.2891427278518677,
#  '1751-1800': 0.3096631169319153,
#  '1801-1825': 0.5373560190200806,
#  '1826-1850': 0.1964428722858429,
#  '1851-1875': 0.2741195559501648,
#  '1876-1900': 0.18998858332633972,
#  '1901-1925': 0.17396743595600128,
#  '1926-1950': 0.21933957934379578,
#  '1951-1975': 0.31523534655570984,
#  '1976-2000': 0.2369401752948761,
#  '2001-2010': 0.2886888086795807,
#  '2011-2016': 0.3022623360157013,
#  '2017-2021': 0.3283306658267975}

# %%
compare_cos(periods, models, 'spesso', 'raccapricciare')
# Out:
# {'1700-1750': 0.45462799072265625,
#  '1751-1800': 0.40400272607803345,
#  '1801-1825': 0.534148633480072,
#  '1826-1850': 0.3236989974975586,
#  '1851-1875': 0.3434657156467438,
#  '1876-1900': 0.2857065796852112,
#  '1901-1925': 0.25758010149002075,
#  '1926-1950': 0.3715881407260895,
#  '1951-1975': 0.5538411140441895,
#  '1976-2000': 0.39661380648612976,
#  '2001-2010': 0.39496728777885437,
#  '2011-2016': 0.482840895652771,
#  '2017-2021': 0.4117305278778076}

# %%
compare_cos(periods, models, 'spesso', 'schifo')
# Out:
# {'1700-1750': 0.3686820864677429,
#  '1751-1800': 0.41164204478263855,
#  '1801-1825': 0.6014887094497681,
#  '1826-1850': 0.38935163617134094,
#  '1851-1875': 0.3243744969367981,
#  '1876-1900': 0.14305084943771362,
#  '1901-1925': 0.19520951807498932,
#  '1926-1950': 0.16416716575622559,
#  '1951-1975': 0.5396373867988586,
#  '1976-2000': 0.28666171431541443,
#  '2001-2010': 0.23804855346679688,
#  '2011-2016': 0.26897895336151123,
#  '2017-2021': 0.2393309772014618}

# %%
compare_cos(periods, models, 'spesso', 'sgomentare')
# Out:
# {'1700-1750': 0.2921445965766907,
#  '1751-1800': 0.535714864730835,
#  '1801-1825': 0.5852087736129761,
#  '1826-1850': 0.3238780200481415,
#  '1851-1875': 0.32328367233276367,
#  '1876-1900': 0.24939683079719543,
#  '1901-1925': 0.28541702032089233,
#  '1926-1950': 0.3196392059326172,
#  '1951-1975': 0.4564412236213684,
#  '1976-2000': 0.25641393661499023,
#  '2001-2010': 0.4104191064834595,
#  '2011-2016': 0.33050528168678284,
#  '2017-2021': 0.31556206941604614}

# %%
compare_cos(periods, models, 'spesso', 'sgomento')
# Out:
# {'1700-1750': 0.4234784245491028,
#  '1751-1800': 0.4966219961643219,
#  '1801-1825': 0.5090105533599854,
#  '1826-1850': 0.276957631111145,
#  '1851-1875': 0.37726473808288574,
#  '1876-1900': 0.15962852537631989,
#  '1901-1925': 0.2692732512950897,
#  '1926-1950': 0.2851559519767761,
#  '1951-1975': 0.5225544571876526,
#  '1976-2000': 0.1810368001461029,
#  '2001-2010': 0.28551945090293884,
#  '2011-2016': 0.2879379689693451,
#  '2017-2021': 0.27889031171798706}

# %%
compare_cos(periods, models, 'spesso', 'spaventare')
# Out:
# {'1700-1750': 0.3485264778137207,
#  '1751-1800': 0.4839612543582916,
#  '1801-1825': 0.5313047170639038,
#  '1826-1850': 0.2516093850135803,
#  '1851-1875': 0.3125494718551636,
#  '1876-1900': 0.21969158947467804,
#  '1901-1925': 0.2223721593618393,
#  '1926-1950': 0.3761630654335022,
#  '1951-1975': 0.42567285895347595,
#  '1976-2000': 0.3042491674423218,
#  '2001-2010': 0.2787415683269501,
#  '2011-2016': 0.35951951146125793,
#  '2017-2021': 0.3990996778011322}

# %%
compare_cos(periods, models, 'spesso', 'spavento')
# Out:
# {'1700-1750': 0.28204625844955444,
#  '1751-1800': 0.31198015809059143,
#  '1801-1825': 0.4831962287425995,
#  '1826-1850': 0.12291967123746872,
#  '1851-1875': 0.22988620400428772,
#  '1876-1900': 0.2014762908220291,
#  '1901-1925': 0.18069423735141754,
#  '1926-1950': 0.28741759061813354,
#  '1951-1975': 0.43851515650749207,
#  '1976-2000': 0.2617422938346863,
#  '2001-2010': 0.2423638552427292,
#  '2011-2016': 0.24953122437000275,
#  '2017-2021': 0.20421595871448517}

# %%
compare_cos(periods, models, 'spesso', 'terrore')
# Out:
# {'1700-1750': 0.22386570274829865,
#  '1751-1800': 0.3231166899204254,
#  '1801-1825': 0.4157634675502777,
#  '1826-1850': 0.1918017566204071,
#  '1851-1875': 0.25038331747055054,
#  '1876-1900': 0.15170563757419586,
#  '1901-1925': 0.16930468380451202,
#  '1926-1950': 0.17749692499637604,
#  '1951-1975': 0.3364669382572174,
#  '1976-2000': 0.2276659458875656,
#  '2001-2010': 0.26135319471359253,
#  '2011-2016': 0.23777993023395538,
#  '2017-2021': 0.29521650075912476}

# %%
plt.figure(figsize=[14, 7])
plt.style.use('seaborn-whitegrid')

data1 = compare_cos(periods, models, 'spesso', 'angoscia')
data2 = compare_cos(periods, models, 'spesso', 'atterrire')
data3 = compare_cos(periods, models, 'spesso', 'panico')
data4 = compare_cos(periods, models, 'spesso', 'paura')
data5 = compare_cos(periods, models, 'spesso', 'raccapricciare')
data6 = compare_cos(periods, models, 'spesso', 'schifo')
data7 = compare_cos(periods, models, 'spesso', 'sgomentare')
data8 = compare_cos(periods, models, 'spesso', 'sgomento')
data9 = compare_cos(periods, models, 'spesso', 'spaventare')
data10 = compare_cos(periods, models, 'spesso', 'spavento')
data11 = compare_cos(periods, models, 'spesso', 'terrore')

# Durchschnitt pro Zeitraum
df = pd.DataFrame([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])
data = dict(df.mean())

x_indexes = list(np.arange(len(data)))
plt.xticks(ticks=x_indexes, labels=data.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.ylim(0, 1)

plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#000000')
plt.plot(x_indexes, data1.values(), label='angoscia', marker='o', color='#00004d')
plt.plot(x_indexes, data2.values(), label='atterrire', marker='o', color='#23014a') 
plt.plot(x_indexes, data3.values(), label='panico', marker='o', color='#380474')
plt.plot(x_indexes, data4.values(), label='paura', marker='o', color='#551a99')
plt.plot(x_indexes, data5.values(), label='raccapricciare', marker='o', color='#6f02f0')
plt.plot(x_indexes, data6.values(), label='schifo', marker='o', color='#000099')
plt.plot(x_indexes, data7.values(), label='sgomentare', marker='o', color='#0000FF')
plt.plot(x_indexes, data8.values(), label='sgomento', marker='o', color='#008fcc')
plt.plot(x_indexes, data9.values(), label='spabentare', marker='o', color='#0BB5FF')
plt.plot(x_indexes, data10.values(), label='spavento', marker='o', color='#80dfff')
plt.plot(x_indexes, data11.values(), label='terrore', marker='o', color='#BFEFFF')
#plt.plot(x_indexes, data.values(), label='mean', marker='o', color='r')

# Regressionslinie
coef = np.polyfit(x_indexes, list(data.values()), 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(x_indexes, poly1d_fn(x_indexes), label='Regressionslinie', linestyle='--', color='r')

plt.xlabel('Zeiträume')
plt.ylabel('Cosinus-Ähnlichkeit')

plt.tight_layout()
plt.margins(0.05, 0.05)
plt.legend(loc='upper right', fontsize='small')

plt.show()
