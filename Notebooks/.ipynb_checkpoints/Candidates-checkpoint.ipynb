# %%
import codecs
from collections import Counter
import nltk
import numpy as np
import os
import pandas as pd
import re
import scipy
import spacy

# %%
df = pd.read_csv('../Korpus/Korpus/corpus_final.csv', sep=',', encoding='utf-8')

# %%
df.rename({'lemmatized text': 'lemmatized_text', 'cleaned tokenized text': 'cleaned_tokenized_text'}, axis=1, inplace=True)

# %%
df.head()
# Out:
#                          doc source                               author  \
# 0  Espositivi.IV.4.Testo.txt  MIDIA           Ludovico Antonio Muratori
# 1      Poesia.IV.1.Testo.txt  MIDIA  Giuseppe Paolucci (Alessi Cillenio)
# 2   Personali.IV.4.Testo.txt  MIDIA                 Vincenzo da Filicaia
# 3   Personali.IV.5.Testo.txt  MIDIA                    Lorenzo Magalotti
# 4      Poesia.IV.4.Testo.txt  MIDIA               Faustina Maratti Zappi
#
#                                  title    year     period   text type  \
# 0                   Antichità italiane  1700.0  1700-1750  espositivo
# 1                               Poesie  1700.0  1700-1750      poesia
# 2  Lettere inedite a Lorenzo Magalotti  1700.0  1700-1750   personale
# 3          Lettere odorose (1693-1705)  1700.0  1700-1750   personale
# 4                               Poesie  1700.0  1700-1750      poesia
#
#                                                 text    words  \
# 0  ﻿IV. 4. Ludovico Antonio Muratori, Antichità i...   8990.0
# 1  IV. 1. Rime degli Arcadi: Alessi Cillenio (Giu...  10862.0
# 2  IV. 4. Vincenzo da Filicaia, Lettere inedite a...  10073.0
# 3  IV. 5. Lorenzo Magalotti, Lettere odorose (169...   8374.0
# 4  IV. 4. Rime degli Arcadi: Aglauro Cidonia (Fau...   3184.0
#
#                                      lemmatized_text  \
# 0  ﻿iv . 4 . Ludovico Antonio muratori , antichit...
# 1  iv . 1 . rima del arcadi : alessi cillenio ( G...
# 2  iv . 4 . Vincenzo da filicaia , lettere inedit...
# 3  iv . 5 . Lorenzo magalotti , lettere odoroso (...
# 4  iv . 4 . rima del arcadi : aglauro cidonia ( f...
#
#                               cleaned_tokenized_text
# 0  [['iv'], [], ['ludovico', 'antonio', 'muratori...
# 1  [['iv'], [], ['rima', 'arcadi', 'alessi', 'cil...
# 2  [['iv'], [], ['vincenzo', 'filicaia', 'lettere...
# 3  [['iv'], [], ['lorenzo', 'magalotti', 'lettere...
# 4  [['iv'], [], ['rima', 'arcadi', 'aglauro', 'ci...

# %%
df.shape
# Out:
# (697296, 11)

# %%
df.text = df.text.fillna('')
df.lemmatized_text = df.lemmatized_text.fillna('')

# %%
# Teilframes pro Zeitraum erstellen

period_frames = []
periods = list(df['period'].unique())
df_periods = dict(tuple(df.groupby(by='period')))

for df, period in zip(df_periods, periods):
    df_period = df_periods[period]
    period_frames.append(df_period)

# %%
# Funktion, die bestimmte Wörter zählt (im lemmatisierten Text)

def count_keywords(df, keywords):
    keyword_dict = {w:w.replace(' ', '_') for w in keywords}

    corpus = ' '.join(df.lemmatized_text).lower()
    for w,w2 in keyword_dict.items():
        corpus = corpus.replace(w,w2)

    all_counts = Counter(corpus.split())
    final_counts = {w:all_counts[w2] for w,w2 in keyword_dict.items()}
    return final_counts

# %%
# mögliche Kandidaten

keywords = ['atrocemente', 'formidabilmente', 'mostruosamente', 'orrendamente', 
            'orribilmente', 'spaventosamente', 'terribilmente', 'tremendamente', 
            'molto', 'angoscia', 'angosciare', 'ansia', 'atterrire', 'panico', 
            'paura', 'raccapricciare', 'raccapriccio', 'schifo', 'sgomentare', 
            'sgomento', 'spaventare', 'spavento', 'terrore', 'domani', 'finora', 
            'ieri', 'oggi', 'presto', 'raramente', 'sempre', 'spesso']

# %%
candidates = {}

for df, period in zip(period_frames, periods):
    res = count_keywords(df, keywords)
    candidates[period] = res

# %%
candidates
# Out:
# {'1700-1750': {'atrocemente': 2,
#   'formidabilmente': 0,
#   'mostruosamente': 2,
#   'orrendamente': 1,
#   'orribilmente': 20,
#   'spaventosamente': 9,
#   'terribilmente': 13,
#   'tremendamente': 0,
#   'molto': 11215,
#   'angoscia': 25,
#   'angosciare': 0,
#   'ansia': 1,
#   'atterrire': 202,
#   'panico': 22,
#   'paura': 583,
#   'raccapricciare': 7,
#   'raccapriccio': 1,
#   'schifo': 11,
#   'sgomentare': 61,
#   'sgomento': 7,
#   'spaventare': 136,
#   'spavento': 391,
#   'terrore': 597,
#   'domani': 56,
#   'finora': 444,
#   'ieri': 25,
#   'oggi': 913,
#   'presto': 509,
#   'raramente': 9,
#   'sempre': 2269,
#   'spesso': 814},
#  '1751-1800': {'atrocemente': 3,
#   'formidabilmente': 0,
#   'mostruosamente': 0,
#   'orrendamente': 1,
#   'orribilmente': 25,
#   'spaventosamente': 1,
#   'terribilmente': 13,
#   'tremendamente': 0,
#   'molto': 16013,
#   'angoscia': 124,
#   'angosciare': 0,
#   'ansia': 2,
#   'atterrire': 134,
#   'panico': 14,
#   'paura': 285,
#   'raccapricciare': 2,
#   'raccapriccio': 8,
#   'schifo': 31,
#   'sgomentare': 18,
#   'sgomento': 4,
#   'spaventare': 138,
#   'spavento': 212,
#   'terrore': 595,
#   'domani': 189,
#   'finora': 271,
#   'ieri': 108,
#   'oggi': 714,
#   'presto': 975,
#   'raramente': 80,
#   'sempre': 3334,
#   'spesso': 1347},
#  '1801-1825': {'atrocemente': 2,
#   'formidabilmente': 0,
#   'mostruosamente': 2,
#   'orrendamente': 10,
#   'orribilmente': 28,
#   'spaventosamente': 2,
#   'terribilmente': 16,
#   'tremendamente': 2,
#   'molto': 11595,
#   'angoscia': 142,
#   'angosciare': 10,
#   'ansia': 6,
#   'atterrire': 96,
#   'panico': 4,
#   'paura': 340,
#   'raccapricciare': 8,
#   'raccapriccio': 9,
#   'schifo': 5,
#   'sgomentare': 14,
#   'sgomento': 4,
#   'spaventare': 238,
#   'spavento': 217,
#   'terrore': 340,
#   'domani': 363,
#   'finora': 125,
#   'ieri': 412,
#   'oggi': 1418,
#   'presto': 670,
#   'raramente': 30,
#   'sempre': 3287,
#   'spesso': 866},
#  '1826-1850': {'atrocemente': 25,
#   'formidabilmente': 2,
#   'mostruosamente': 3,
#   'orrendamente': 11,
#   'orribilmente': 61,
#   'spaventosamente': 4,
#   'terribilmente': 33,
#   'tremendamente': 6,
#   'molto': 12414,
#   'angoscia': 306,
#   'angosciare': 30,
#   'ansia': 82,
#   'atterrire': 387,
#   'panico': 63,
#   'paura': 710,
#   'raccapricciare': 38,
#   'raccapriccio': 38,
#   'schifo': 32,
#   'sgomentare': 119,
#   'sgomento': 60,
#   'spaventare': 556,
#   'spavento': 671,
#   'terrore': 1375,
#   'domani': 239,
#   'finora': 339,
#   'ieri': 169,
#   'oggi': 1086,
#   'presto': 906,
#   'raramente': 47,
#   'sempre': 3464,
#   'spesso': 1487},
#  '1876-1900': {'atrocemente': 119,
#   'formidabilmente': 16,
#   'mostruosamente': 36,
#   'orrendamente': 45,
#   'orribilmente': 223,
#   'spaventosamente': 81,
#   'terribilmente': 209,
#   'tremendamente': 67,
#   'molto': 24739,
#   'angoscia': 1202,
#   'angosciare': 55,
#   'ansia': 697,
#   'atterrire': 496,
#   'panico': 59,
#   'paura': 4475,
#   'raccapricciare': 95,
#   'raccapriccio': 222,
#   'schifo': 219,
#   'sgomentare': 391,
#   'sgomento': 813,
#   'spaventare': 1640,
#   'spavento': 1199,
#   'terrore': 1931,
#   'domani': 5289,
#   'finora': 892,
#   'ieri': 2764,
#   'oggi': 5021,
#   'presto': 4100,
#   'raramente': 309,
#   'sempre': 9629,
#   'spesso': 3427},
#  '1901-1925': {'atrocemente': 59,
#   'formidabilmente': 14,
#   'mostruosamente': 21,
#   'orrendamente': 33,
#   'orribilmente': 198,
#   'spaventosamente': 104,
#   'terribilmente': 169,
#   'tremendamente': 19,
#   'molto': 17134,
#   'angoscia': 1048,
#   'angosciare': 30,
#   'ansia': 549,
#   'atterrire': 340,
#   'panico': 84,
#   'paura': 3258,
#   'raccapricciare': 19,
#   'raccapriccio': 93,
#   'schifo': 118,
#   'sgomentare': 245,
#   'sgomento': 541,
#   'spaventare': 876,
#   'spavento': 657,
#   'terrore': 1343,
#   'domani': 4313,
#   'finora': 604,
#   'ieri': 1746,
#   'oggi': 3645,
#   'presto': 2846,
#   'raramente': 337,
#   'sempre': 6433,
#   'spesso': 2958},
#  '1926-1950': {'atrocemente': 37,
#   'formidabilmente': 9,
#   'mostruosamente': 15,
#   'orrendamente': 27,
#   'orribilmente': 90,
#   'spaventosamente': 68,
#   'terribilmente': 176,
#   'tremendamente': 24,
#   'molto': 13130,
#   'angoscia': 814,
#   'angosciare': 35,
#   'ansia': 578,
#   'atterrire': 225,
#   'panico': 60,
#   'paura': 2089,
#   'raccapricciare': 17,
#   'raccapriccio': 87,
#   'schifo': 130,
#   'sgomentare': 103,
#   'sgomento': 350,
#   'spaventare': 401,
#   'spavento': 408,
#   'terrore': 1122,
#   'domani': 2438,
#   'finora': 285,
#   'ieri': 1176,
#   'oggi': 2818,
#   'presto': 1244,
#   'raramente': 110,
#   'sempre': 3943,
#   'spesso': 1113},
#  '1951-1975': {'atrocemente': 16,
#   'formidabilmente': 0,
#   'mostruosamente': 6,
#   'orrendamente': 6,
#   'orribilmente': 21,
#   'spaventosamente': 26,
#   'terribilmente': 14,
#   'tremendamente': 3,
#   'molto': 9315,
#   'angoscia': 116,
#   'angosciare': 8,
#   'ansia': 135,
#   'atterrire': 15,
#   'panico': 39,
#   'paura': 353,
#   'raccapricciare': 2,
#   'raccapriccio': 10,
#   'schifo': 18,
#   'sgomentare': 13,
#   'sgomento': 38,
#   'spaventare': 55,
#   'spavento': 55,
#   'terrore': 151,
#   'domani': 233,
#   'finora': 86,
#   'ieri': 309,
#   'oggi': 1170,
#   'presto': 381,
#   'raramente': 49,
#   'sempre': 2459,
#   'spesso': 783},
#  '1976-2000': {'atrocemente': 97,
#   'formidabilmente': 5,
#   'mostruosamente': 78,
#   'orrendamente': 171,
#   'orribilmente': 156,
#   'spaventosamente': 140,
#   'terribilmente': 1045,
#   'tremendamente': 348,
#   'molto': 36297,
#   'angoscia': 5930,
#   'angosciare': 495,
#   'ansia': 6861,
#   'atterrire': 170,
#   'panico': 4847,
#   'paura': 10244,
#   'raccapricciare': 7,
#   'raccapriccio': 192,
#   'schifo': 1047,
#   'sgomentare': 241,
#   'sgomento': 1599,
#   'spaventare': 4775,
#   'spavento': 1001,
#   'terrore': 7062,
#   'domani': 8103,
#   'finora': 7345,
#   'ieri': 11037,
#   'oggi': 12097,
#   'presto': 7678,
#   'raramente': 3040,
#   'sempre': 13329,
#   'spesso': 8530},
#  '2001-2010': {'atrocemente': 147,
#   'formidabilmente': 35,
#   'mostruosamente': 214,
#   'orrendamente': 215,
#   'orribilmente': 339,
#   'spaventosamente': 396,
#   'terribilmente': 1938,
#   'tremendamente': 1070,
#   'molto': 26935,
#   'angoscia': 2891,
#   'angosciare': 866,
#   'ansia': 2909,
#   'atterrire': 623,
#   'panico': 2961,
#   'paura': 4883,
#   'raccapricciare': 33,
#   'raccapriccio': 385,
#   'schifo': 2935,
#   'sgomentare': 385,
#   'sgomento': 2029,
#   'spaventare': 2783,
#   'spavento': 1661,
#   'terrore': 2944,
#   'domani': 3719,
#   'finora': 2831,
#   'ieri': 4511,
#   'oggi': 7014,
#   'presto': 3242,
#   'raramente': 2609,
#   'sempre': 8348,
#   'spesso': 4090},
#  '2011-2016': {'atrocemente': 139,
#   'formidabilmente': 19,
#   'mostruosamente': 203,
#   'orrendamente': 191,
#   'orribilmente': 329,
#   'spaventosamente': 357,
#   'terribilmente': 1337,
#   'tremendamente': 1112,
#   'molto': 23414,
#   'angoscia': 1403,
#   'angosciare': 680,
#   'ansia': 1631,
#   'atterrire': 630,
#   'panico': 1559,
#   'paura': 2976,
#   'raccapricciare': 22,
#   'raccapriccio': 193,
#   'schifo': 1477,
#   'sgomentare': 257,
#   'sgomento': 1287,
#   'spaventare': 1508,
#   'spavento': 1384,
#   'terrore': 1746,
#   'domani': 2744,
#   'finora': 1595,
#   'ieri': 3486,
#   'oggi': 5210,
#   'presto': 1928,
#   'raramente': 1310,
#   'sempre': 6623,
#   'spesso': 2411},
#  '2017-2021': {'atrocemente': 140,
#   'formidabilmente': 26,
#   'mostruosamente': 300,
#   'orrendamente': 208,
#   'orribilmente': 349,
#   'spaventosamente': 440,
#   'terribilmente': 678,
#   'tremendamente': 688,
#   'molto': 23631,
#   'angoscia': 812,
#   'angosciare': 323,
#   'ansia': 888,
#   'atterrire': 511,
#   'panico': 960,
#   'paura': 1877,
#   'raccapricciare': 48,
#   'raccapriccio': 212,
#   'schifo': 827,
#   'sgomentare': 244,
#   'sgomento': 729,
#   'spaventare': 924,
#   'spavento': 672,
#   'terrore': 876,
#   'domani': 1653,
#   'finora': 1018,
#   'ieri': 2888,
#   'oggi': 5105,
#   'presto': 1276,
#   'raramente': 732,
#   'sempre': 6136,
#   'spesso': 1882}}

# %%
table = pd.DataFrame.from_dict(candidates, orient='index')
table
# Out:
#            atrocemente  formidabilmente  mostruosamente  orrendamente  \
# 1700-1750            2                0               2             1
# 1751-1800            3                0               0             1
# 1801-1825            2                0               2            10
# 1826-1850           25                2               3            11
# 1876-1900          119               16              36            45
# 1901-1925           59               14              21            33
# 1926-1950           37                9              15            27
# 1951-1975           16                0               6             6
# 1976-2000           97                5              78           171
# 2001-2010          147               35             214           215
# 2011-2016          139               19             203           191
# 2017-2021          140               26             300           208
#
#            orribilmente  spaventosamente  terribilmente  tremendamente  molto  \
# 1700-1750            20                9             13              0  11215
# 1751-1800            25                1             13              0  16013
# 1801-1825            28                2             16              2  11595
# 1826-1850            61                4             33              6  12414
# 1876-1900           223               81            209             67  24739
# 1901-1925           198              104            169             19  17134
# 1926-1950            90               68            176             24  13130
# 1951-1975            21               26             14              3   9315
# 1976-2000           156              140           1045            348  36297
# 2001-2010           339              396           1938           1070  26935
# 2011-2016           329              357           1337           1112  23414
# 2017-2021           349              440            678            688  23631
#
#            angoscia  ...  spavento  terrore  domani  finora   ieri   oggi  \
# 1700-1750        25  ...       391      597      56     444     25    913
# 1751-1800       124  ...       212      595     189     271    108    714
# 1801-1825       142  ...       217      340     363     125    412   1418
# 1826-1850       306  ...       671     1375     239     339    169   1086
# 1876-1900      1202  ...      1199     1931    5289     892   2764   5021
# 1901-1925      1048  ...       657     1343    4313     604   1746   3645
# 1926-1950       814  ...       408     1122    2438     285   1176   2818
# 1951-1975       116  ...        55      151     233      86    309   1170
# 1976-2000      5930  ...      1001     7062    8103    7345  11037  12097
# 2001-2010      2891  ...      1661     2944    3719    2831   4511   7014
# 2011-2016      1403  ...      1384     1746    2744    1595   3486   5210
# 2017-2021       812  ...       672      876    1653    1018   2888   5105
#
#            presto  raramente  sempre  spesso
# 1700-1750     509          9    2269     814
# 1751-1800     975         80    3334    1347
# 1801-1825     670         30    3287     866
# 1826-1850     906         47    3464    1487
# 1876-1900    4100        309    9629    3427
# 1901-1925    2846        337    6433    2958
# 1926-1950    1244        110    3943    1113
# 1951-1975     381         49    2459     783
# 1976-2000    7678       3040   13329    8530
# 2001-2010    3242       2609    8348    4090
# 2011-2016    1928       1310    6623    2411
# 2017-2021    1276        732    6136    1882
#
# [12 rows x 31 columns]

# %%
table.to_csv('../Korpus/Korpus/candidates_after_lemmatization.csv')
