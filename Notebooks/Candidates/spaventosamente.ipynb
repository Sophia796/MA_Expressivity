# %% [markdown]
# # Manuelle Auswertung der Kandidaten

# %% [markdown]
# ## spaventosamente

# %%
import codecs
from collections import Counter
from IPython.display import Markdown, display
import nltk
import numpy as np
import os
import pandas as pd
import re
import scipy
import spacy

# %%
df = pd.read_csv('../../Korpus/Korpus/corpus_norm.csv', sep=',', encoding='utf-8')

# %%
df.shape
# Out:
# (134168, 11)

# %%
df.text = df.text.fillna('')
df.lemmatized_text = df.lemmatized_text.fillna('')
df.cleaned_text = df.cleaned_text.fillna('')

# %%
def countTerr(str):
    wordslist = list(str.split())
    return wordslist.count('spaventosamente')

# %%
df['spaventosamente'] = df['cleaned_text'].astype(str).apply(countTerr)

# %%
# nur Texte behalten, in denen spaventosamente vorkommt

df_terr = df[df['spaventosamente'] >= 1]

# %%
df_terr.head()
# Out:
#                         doc     source                      author  \
# 31           BibItVico1.txt      BibIt           Giambattista Vico
# 4623  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
# 4624  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
# 4625  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
# 4626  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
#
#                                                   title    year     period  \
# 31                            Principi di scienza nuova  1725.0  1700-1750
# 4623  Annali d''Italia, vol. 2: dal principio dell''...  1749.0  1700-1750
# 4624  Annali d''Italia, vol. 5: dal principio dell''...  1749.0  1700-1750
# 4625  Annali d''Italia, vol. 1: dal principio dell''...  1749.0  1700-1750
# 4626  Annali d''Italia, vol. 2: dal principio dell''...  1749.0  1700-1750
#
#              text_type     words  \
# 31          espositivo  155604.0
# 4623  prosa letteraria      39.0
# 4624  prosa letteraria      40.0
# 4625  prosa letteraria      39.0
# 4626  prosa letteraria      35.0
#
#                                                    text  \
# 31    SPIEGAZIONE DELLA DIPINTURA PROPOSTA AL FRONTI...
# 4623  ecclesiastica. Terribile avvenimento ancora de...
# 4624  enorme dissolutezza che regnava allora in quel...
# 4625  scrittore di questi tempi, intorno alla cui pa...
# 4626  da Agnello Ravennate[2869], che nell''anno V d...
#
#                                            cleaned_text  \
# 31    spiegazione della dipintura proposta al fronti...
# 4623  ecclesiastica. terribile avvenimento ancora de...
# 4624  enorme dissolutezza che regnava allora in quel...
# 4625  scrittore di questi tempi, intorno alla cui pa...
# 4626  da agnello ravennate      , che nell  anno v d...
#
#                                         lemmatized_text  spaventosamente
# 31    spiegazione della dipintura proposta al fronti...                1
# 4623  ecclesiastico . terribile avvenimento ancora d...                1
# 4624  enorme dissolutezza che regnare allora in quel...                1
# 4625  scrittore di questo tempo , intorno alla cui p...                1
# 4626  da agnello ravennate[2869 ] , che nell''anno v...                1

# %%
# Einzeldataframes für die Zeiträume

df_periods = dict(tuple(df_terr.groupby(by='period')))

# %%
df1 = df_periods['1700-1750']
#df2 = df_periods['1751-1800']
df3 = df_periods['1801-1850']
df4 = df_periods['1851-1900']
df5 = df_periods['1901-1950']
df6 = df_periods['1951-2000']
df7 = df_periods['2001-2021']

# %% [markdown]
# ### Hilfsfunktionen

# %%
# Funktion, die die Sätze ausgibt, in der ein bestimmtes Wort vorkommt

def find_sentences_with_keyword(document, keyword):
    
    sentlist = []
    
    for sentence in document:
        
        if keyword.lower() in sentence.lower():
            sentence = re.sub('\n', ' ', sentence)          
            sentlist.append(sentence)
                         
    return sentlist

# %%
def return_sentences_with_keyword(text):
    
    document = nltk.sent_tokenize(text)
    res = find_sentences_with_keyword(document, 'spaventosamente')
    result = list(res)
    
    return result

# %% [markdown]
# ### Zeitraum 1: 1700-1750

# %%
df1['sentence'] = df1['cleaned_text'].astype(str).apply(return_sentences_with_keyword)

# %%
# Spalten neu anordnen und unnötige entfernen

res1 = df1[['doc', 'source', 'author', 'title', 'year', 'period', 'text_type', 'sentence']]

# %%
res1
# Out:
#                         doc     source                      author  \
# 31           BibItVico1.txt      BibIt           Giambattista Vico
# 4623  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
# 4624  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
# 4625  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
# 4626  GBspaventosamente.csv  Gutenberg   Lodovico Antonio Muratori
#
#                                                   title    year     period  \
# 31                            Principi di scienza nuova  1725.0  1700-1750
# 4623  Annali d''Italia, vol. 2: dal principio dell''...  1749.0  1700-1750
# 4624  Annali d''Italia, vol. 5: dal principio dell''...  1749.0  1700-1750
# 4625  Annali d''Italia, vol. 1: dal principio dell''...  1749.0  1700-1750
# 4626  Annali d''Italia, vol. 2: dal principio dell''...  1749.0  1700-1750
#
#              text_type                                           sentence
# 31          espositivo  [altronde era natura tutta fiera ed immane; ma...
# 4623  prosa letteraria  [terribile avvenimento ancora dell  anno prese...
# 4624  prosa letteraria  [essendo caduto uno smisurato diluvio d  acque...
# 4625  prosa letteraria  [nel primo dì di novembre cominciò spaventosam...
# 4626  prosa letteraria  [da agnello ravennate      , che nell  anno v ...

# %% [markdown]
# ### Zeitraum 3: 1801-1850

# %%
df3['sentence'] = df3['cleaned_text'].astype(str).apply(return_sentences_with_keyword)

# %%
# Spalten neu anordnen und unnötige entfernen

res3 = df3[['doc', 'source', 'author', 'title', 'year', 'period', 'text_type', 'sentence']]

# %%
res3.head()
# Out:
#                          doc source              author  \
# 7529  Poesia.IV.25.Testo.txt  MIDIA     Giuseppe Parini
# 7607  Poesia.IV.43.Testo.txt  MIDIA      Tommaso Grossi
# 7930      BibItManzoni20.txt  BibIt  Alessandro Manzoni
#
#                             title    year     period         text_type  \
# 7529                 Il Giorno II  1801.0  1801-1850            poesia
# 7607                    Ildegonda  1820.0  1801-1850            poesia
# 7930  Storia della colonna infame  1840.0  1801-1850  prosa letteraria
#
#                                                sentence
# 7529  [oggi la diva urania il crin compose; e gl irt...
# 7607  [dal sepolcro ove han stanza l ossa ignude  ma...
# 7930  [e tale, oso dire, fu anche l intento primitiv...

# %% [markdown]
# ### Zeitraum 4: 1851-1900

# %%
df4['sentence'] = df4['cleaned_text'].astype(str).apply(return_sentences_with_keyword)

# %%
# Spalten neu anordnen und unnötige entfernen

res4 = df4[['doc', 'source', 'author', 'title', 'year', 'period', 'text_type', 'sentence']]

# %%
res4.head()
# Out:
#                         doc       source                author  \
# 8261  GBspaventosamente.csv    Gutenberg        Silvio Pellico
# 8304        LLBersezio1.txt  Liber Liber     Vittorio Bersezio
# 8311    BibItTarchetti1.txt        BibIt  Ugo Iginio Tarchetti
# 8313         LLBarrili5.txt  Liber Liber  Anton Giulio Barrili
# 8314             li0477.txt     CLiGS Ro  Iginio Ugo Tarchetti
#
#                        title    year     period         text_type  \
# 8261                Rafaella  1853.0  1851-1900  prosa letteraria
# 8304  La carità del prossimo  1868.0  1851-1900  prosa letteraria
# 8311                   Fosca  1869.0  1851-1900  prosa letteraria
# 8313        L'olmo e l'edera  1869.0  1851-1900  prosa letteraria
# 8314                   Fosca  1869.0  1851-1900  prosa letteraria
#
#                                                sentence
# 8261  [, e divoravano cadaveri insepolti, o sentendo...
# 8304  [col, gli occhi spaventosamente fuor del punto...
# 8311  [tutto ciò mi pareva allora assai puerile; pur...
# 8313            [vero tutto ci,  spaventosamente vero!]
# 8314  [tutto ciò mi pareva allora assai puerile; pur...

# %% [markdown]
# ### Zeitraum 5: 1901-1950

# %%
df5['sentence'] = df5['cleaned_text'].astype(str).apply(return_sentences_with_keyword)

# %%
# Spalten neu anordnen und unnötige entfernen

res5 = df5[['doc', 'source', 'author', 'title', 'year', 'period', 'text_type', 'sentence']]

# %%
res5.head()
# Out:
#                            doc       source  \
# 8682     GBspaventosamente.csv    Gutenberg
# 8683         LLInvernizio1.txt  Liber Liber
# 8685     GBspaventosamente.csv    Gutenberg
# 8686     GBspaventosamente.csv    Gutenberg
# 8700  Personali.V.12.Testo.txt        MIDIA
#
#                                      author  \
# 8682                          Gaetano Negri
# 8683                    Carolina Invernizio
# 8685                          Gaetano Negri
# 8686                          Gaetano Negri
# 8700  Guido Gozzano / Amalia Guglielminetti
#
#                                                   title    year     period  \
# 8682  L''Imperatore Giuliano l''Apostata: studio sto...  1901.0  1901-1950
# 8683                           I misteri delle soffitte  1901.0  1901-1950
# 8685  L''Imperatore Giuliano l''Apostata: studio sto...  1901.0  1901-1950
# 8686  L''Imperatore Giuliano l''Apostata: studio sto...  1901.0  1901-1950
# 8700                                    Lettere d’amore  1903.0  1901-1950
#
#              text_type                                           sentence
# 8682  prosa letteraria  [e il concilio di milano si sciolse, dopo aver...
# 8683  prosa letteraria  [la giovane era sempre spaventosamente pallida...
# 8685  prosa letteraria  [anche il cristianesimo non seppe tenersi immu...
# 8686  prosa letteraria  [la sua filosofia diventa spaventosamente comp...
# 8700         personale  [la ne  cessit tipografica mi costrinse a ridu...

# %% [markdown]
# ### Zeitraum 6: 1951-2000

# %%
df6['sentence'] = df6['cleaned_text'].astype(str).apply(return_sentences_with_keyword)

# %%
# Spalten neu anordnen und unnötige entfernen

res6 = df6[['doc', 'source', 'author', 'title', 'year', 'period', 'text_type', 'sentence']]

# %%
res6.head()
# Out:
#                           doc       source                       author  \
# 10772  diacorisGuareschi1.txt     DiaCoris           Giovanni Guareschi
# 10778   diacorisPoggiali1.txt     DiaCoris  Ciro Poggiali / Il Borghese
# 10802           LLGrande1.txt  Liber Liber                 Luigi Grande
# 10858    diacorisBuzzati3.txt     DiaCoris                 Dino Buzzati
# 10957      diacorisBrera1.txt     DiaCoris                 Gianni Brera
#
#                                               title    year     period  \
# 10772                     Corrierino delle famiglie  1954.0  1951-2000
# 10778              La liquidazione dei conti Manzon  1954.0  1951-2000
# 10802                              Diritto all'ozio  1956.0  1951-2000
# 10858                             Sessanta racconti  1958.0  1951-2000
# 10957  Due volte Livio Berruti eguaglia il mondiale  1960.0  1951-2000
#
#               text_type                                           sentence
# 10772  prosa letteraria  [scritte murali si fa un contratto è necessari...
# 10778            stampa  [quando fu poi scoperto il suo cadavere sotto ...
# 10802  prosa letteraria  [siccome quando la sorte ci si mette non rispa...
# 10858  prosa letteraria  [e accanto le sedeva , immoto , un bambino bel...
# 10957            stampa  [galoppano alle sue spalle diavoli orrendi , o...

# %% [markdown]
# ### Zeitraum 7: 2001-2021

# %%
df7['sentence'] = df7['cleaned_text'].astype(str).apply(return_sentences_with_keyword)

# %%
# Spalten neu anordnen und unnötige entfernen

res7 = df7[['doc', 'source', 'author', 'title', 'year', 'period', 'text_type', 'sentence']]

# %%
res7.head()
# Out:
#                            doc    source  \
# 47255  diacorisBoncinelli1.txt  DiaCoris
# 47984    IWspaventosamente.csv     itWaC
# 48015    IWspaventosamente.csv     itWaC
# 48051    IWspaventosamente.csv     itWaC
# 48062    IWspaventosamente.csv     itWaC
#
#                                                   author  \
# 47255                       Edoardo Boncinelli / Liberal
# 47984  http://immaginazione.splinder.com/archive/2003-10
# 48015  http://gamescenter.m4d.it/recensione.php?id_r=...
# 48051  http://www.cronologia.it/storia/mondiale/cina0...
# 48062  http://www.campaniasuweb.it/archivio/numero46/...
#
#                                                    title    year     period  \
# 47255                                  Viva l'homo faber  2001.0  2001-2021
# 47984  http://immaginazione.splinder.com/archive/2003-10  2006.0  2001-2021
# 48015  http://gamescenter.m4d.it/recensione.php?id_r=...  2006.0  2001-2021
# 48051  http://www.cronologia.it/storia/mondiale/cina0...  2006.0  2001-2021
# 48062  http://www.campaniasuweb.it/archivio/numero46/...  2006.0  2001-2021
#
#       text_type                                           sentence
# 47255    stampa  [quello che è aumentato spaventosamente è il n...
# 47984       web  [: nel momento in cui qualcuno ci ascolta dal ...
# 48015       web  [il gioco è spaventosamente arcade   vecchio s...
# 48051       web  [agricola cinese è praticamente paralizzata, i...
# 48062       web  [e sufficiente; inoltre si è stimato che c   è...

# %% [markdown]
# ### Zusammenfügen und Speichern

# %%
res = pd.concat([res1, res3, res4, res5, res6, res7], 
                keys=['1700-1750', '1801-1850', '1851-1900', '1901-1950', '1951-2000', '2001-2021'])

# %%
res
# Out:
#                                       doc        source  \
# 1700-1750 31               BibItVico1.txt         BibIt
#           4623      GBspaventosamente.csv     Gutenberg
#           4624      GBspaventosamente.csv     Gutenberg
#           4625      GBspaventosamente.csv     Gutenberg
#           4626      GBspaventosamente.csv     Gutenberg
# ...                                   ...           ...
# 2001-2021 123457  TT20spaventosamente.csv  itTenten2020
#           123506  TT20spaventosamente.csv  itTenten2020
#           123521  TT20spaventosamente.csv  itTenten2020
#           123571  TT20spaventosamente.csv  itTenten2020
#           123601  TT20spaventosamente.csv  itTenten2020
#
#                                       author  \
# 1700-1750 31               Giambattista Vico
#           4623     Lodovico Antonio Muratori
#           4624     Lodovico Antonio Muratori
#           4625     Lodovico Antonio Muratori
#           4626     Lodovico Antonio Muratori
# ...                                      ...
# 2001-2021 123457     parlamentoduesicilie.it
#           123506                 farefilm.it
#           123521                popsoarte.it
#           123571              metanoauto.com
#           123601                blogspot.com
#
#                                                               title    year  \
# 1700-1750 31                              Principi di scienza nuova  1725.0
#           4623    Annali d''Italia, vol. 2: dal principio dell''...  1749.0
#           4624    Annali d''Italia, vol. 5: dal principio dell''...  1749.0
#           4625    Annali d''Italia, vol. 1: dal principio dell''...  1749.0
#           4626    Annali d''Italia, vol. 2: dal principio dell''...  1749.0
# ...                                                             ...     ...
# 2001-2021 123457                            parlamentoduesicilie.it  2020.0
#           123506                                        farefilm.it  2020.0
#           123521                                       popsoarte.it  2020.0
#           123571                                     metanoauto.com  2020.0
#           123601                                       blogspot.com  2020.0
#
#                      period         text_type  \
# 1700-1750 31      1700-1750        espositivo
#           4623    1700-1750  prosa letteraria
#           4624    1700-1750  prosa letteraria
#           4625    1700-1750  prosa letteraria
#           4626    1700-1750  prosa letteraria
# ...                     ...               ...
# 2001-2021 123457  2001-2021               web
#           123506  2001-2021               web
#           123521  2001-2021               web
#           123571  2001-2021               web
#           123601  2001-2021               web
#
#                                                            sentence
# 1700-1750 31      [altronde era natura tutta fiera ed immane; ma...
#           4623    [terribile avvenimento ancora dell  anno prese...
#           4624    [essendo caduto uno smisurato diluvio d  acque...
#           4625    [nel primo dì di novembre cominciò spaventosam...
#           4626    [da agnello ravennate      , che nell  anno v ...
# ...                                                             ...
# 2001-2021 123457  [che felice definirebbe  neoborbonici   e che ...
#           123506  [ma appena il buio della notte inizierà ad ins...
#           123521  [alla base i pezzi di ghiaccio si accumulano g...
#           123571  [ogni    m c  era una rotonda, un semaforo, un...
#           123601  [ necessitiamo velocemente di un posto dove se...
#
# [435 rows x 8 columns]

# %%
res.to_csv('sentences/spaventosamente.csv', sep=';', encoding='ANSI')

# %%
# einzeln 

res1.to_csv('sentences/spaventosamente1.csv', sep=';', encoding='ANSI')
#res2.to_csv('sentences/spaventosamente2.csv', sep=';', encoding='ANSI')
res3.to_csv('sentences/spaventosamente3.csv', sep=';', encoding='ANSI')
res4.to_csv('sentences/spaventosamente4.csv', sep=';', encoding='ANSI')
res5.to_csv('sentences/spaventosamente5.csv', sep=';', encoding='ANSI')
res6.to_csv('sentences/spaventosamente6.csv', sep=';', encoding='ANSI')
res7.to_csv('sentences/spaventosamente7.csv', sep=';', encoding='ANSI')
