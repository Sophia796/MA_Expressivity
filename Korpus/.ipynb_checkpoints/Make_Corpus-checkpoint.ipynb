# %% [markdown]
# # Erstellung des Korpus

# %%
import glob
import numpy as np
import os
import pandas as pd
import re

# %%
# Metadaten einlesen

md = pd.read_csv('metadata.csv', sep=';', encoding='utf-8')

# %%
files = []

for file in os.listdir('Texte'):
    files.append(file)

# %%
# Texte einlesen 

data = []

for file in os.listdir('Texte'):
    with open(os.path.join('Texte', file),'r', encoding='utf-8', errors='ignore') as myfile:
        data.append(myfile.read())

# %%
# Metadaten und Texte zusammenfügen (matcht den Dokumentnamen)

corpus = pd.DataFrame({'file': files, 'text': data})

df = pd.merge(md, corpus, how='left', left_on='doc', right_on='file')

# %%
# Wörter zählen und hinzfügen

df['words'] = df['text'].str.count(r'\w+')

# %%
# Spalten neu anordnen und unnötige entfernen

df = df[['doc', 'source', 'author', 'title', 'year', 'text_type', 'text', 'words']]

# %%
df.head()
# Out:
#                          doc source                               author  \
# 0      Poesia.IV.4.Testo.txt  MIDIA               Faustina Maratti Zappi
# 1     Poesia.IV.11.Testo.txt  MIDIA            Giambattista Felice Zappi
# 2      Poesia.IV.1.Testo.txt  MIDIA  Giuseppe Paolucci (Alessi Cillenio)
# 3   Personali.IV.5.Testo.txt  MIDIA                    Lorenzo Magalotti
# 4  Espositivi.IV.4.Testo.txt  MIDIA           Ludovico Antonio Muratori
#
#                          title  year   text_type  \
# 0                       Poesie  1700      poesia
# 1                       Poesie  1700      poesia
# 2                       Poesie  1700      poesia
# 3  Lettere odorose (1693-1705)  1700   personale
# 4           Antichità italiane  1700  espositivo
#
#                                                 text    words
# 0  IV. 4. Rime degli Arcadi: Aglauro Cidonia (Fau...   3184.0
# 1  IV. 11. Rime degli arcadi: Tirsi Leucasio (Gio...   6113.0
# 2  IV. 1. Rime degli Arcadi: Alessi Cillenio (Giu...  10862.0
# 3  IV. 5. Lorenzo Magalotti, Lettere odorose (169...   8374.0
# 4  ﻿IV. 4. Ludovico Antonio Muratori, Antichità i...   8990.0

# %%
df.shape
# Out:
# (1635, 8)

# %%
# KWIC-Listen 
# (vorher einzeln in einheitliche Form gebracht, siehe Vorbereitungscode in den Ordnern der jeweiligen Korpora)

directory = 'KWIC'
kwic_files = glob.glob(os.path.join(directory, '*.csv'))

# %%
# alle KWIC-Listen einlesen 

frames = []

for kwic_file in kwic_files:
    df_new = pd.read_csv(kwic_file, sep=',', encoding='utf-8')
    frames.append(df_new)

# %%
# zu einem Dataframe zusammenfügen 

df_big = pd.concat(frames)

# %%
df_big.head()
# Out:
#                                    doc           source  \
# 0  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 1  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 2  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 3  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 4  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
#
#                                               author  \
# 0  http://www.dica33.it/argomenti/tossicologia/dr...
# 1  http://www.corriere.it/Primo_Piano/Spettacoli/...
# 2  http://www.corriere.it/Primo_Piano/Cronache/20...
# 3  http://www.kwmusica.kataweb.it/kwmusica/pp_sch...
# 4  http://www.mytech.it/news/articolo/idA02800106...
#
#                                                title    year text_type  \
# 0  http://www.dica33.it/argomenti/tossicologia/dr...  2005.0    stampa
# 1  http://www.corriere.it/Primo_Piano/Spettacoli/...  2005.0    stampa
# 2  http://www.corriere.it/Primo_Piano/Cronache/20...  2005.0    stampa
# 3  http://www.kwmusica.kataweb.it/kwmusica/pp_sch...  2005.0    stampa
# 4  http://www.mytech.it/news/articolo/idA02800106...  2005.0    stampa
#
#                                                 text  words
# 0  Il programma delle attività prevede il 27, 28 ...     24
# 1  E cos ieri, parlando a Bari, il leader ha pron...     22
# 2  Cina-Grecia è stata l’unica partita con un val...     26
# 3  I bambini, che avrebbero dovuto frequentare la...     31
# 4  La dignità della persona va rispettata e tutel...     13

# %%
df_big.shape
# Out:
# (430324, 8)

# %%
# KWIC-Listen und selbst erstelltes Korpus zu einem zusammenfügen

df_bigger = pd.concat([df_big, df], axis=0, join='outer', ignore_index=False)

# %%
df_bigger.head()
# Out:
#                                    doc           source  \
# 0  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 1  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 2  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 3  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
# 4  ita_news_2005-2009_1M-sentences.txt  Corpora Italian
#
#                                               author  \
# 0  http://www.dica33.it/argomenti/tossicologia/dr...
# 1  http://www.corriere.it/Primo_Piano/Spettacoli/...
# 2  http://www.corriere.it/Primo_Piano/Cronache/20...
# 3  http://www.kwmusica.kataweb.it/kwmusica/pp_sch...
# 4  http://www.mytech.it/news/articolo/idA02800106...
#
#                                                title    year text_type  \
# 0  http://www.dica33.it/argomenti/tossicologia/dr...  2005.0    stampa
# 1  http://www.corriere.it/Primo_Piano/Spettacoli/...  2005.0    stampa
# 2  http://www.corriere.it/Primo_Piano/Cronache/20...  2005.0    stampa
# 3  http://www.kwmusica.kataweb.it/kwmusica/pp_sch...  2005.0    stampa
# 4  http://www.mytech.it/news/articolo/idA02800106...  2005.0    stampa
#
#                                                 text  words
# 0  Il programma delle attività prevede il 27, 28 ...   24.0
# 1  E cos ieri, parlando a Bari, il leader ha pron...   22.0
# 2  Cina-Grecia è stata l’unica partita con un val...   26.0
# 3  I bambini, che avrebbero dovuto frequentare la...   31.0
# 4  La dignità della persona va rispettata e tutel...   13.0

# %%
df_bigger.shape
# Out:
# (431959, 8)

# %%
# Text von Tags befreien

def parser(text):
    return re.sub('<[^<]+?>', '', str(text))

df_bigger['text'] = df_bigger.text.apply(parser)

# %%
# NaN durch 0 ersetzen (nur für den Fall, um spätere Fehler zu vermeiden)

df_bigger = df_bigger.fillna(0)

# %%
# chronologisch ordnen

df_bigger = df_bigger.sort_values(by=['year'])

# %%
# Text bereinigen 

def clean_text(text):
    clean = re.sub('[^A-Za-z_àÀèÈìÌòÒùÙáÁéÉíÍóÓúÚ.,;:?!]',' ', text).lower()
    return clean

# Sicherstellen, dass nach Punktuation ein Whitespace ist (wichtig für Tokenisierung)

def proof_punctuation(text):
    proofed = re.sub(r'(?<=[.,;:?!])(?=[^\s])', r' ', text)
    return proofed

# %%
df_bigger['filtered_text'] = df_bigger['text'].astype(str).apply(clean_text)

# %%
df_bigger['cleaned_text'] = df_bigger['filtered_text'].astype(str).apply(proof_punctuation)

# %%
# Spalten neu anordnen und unnötige entfernen

df_final = df_bigger[['doc', 'source', 'author', 'title', 'year', 'text_type', 'words', 'text', 'cleaned_text']]

# %%
df_final
# Out:
#                                  doc source  \
# 0              Poesia.IV.4.Testo.txt  MIDIA
# 1             Poesia.IV.11.Testo.txt  MIDIA
# 2              Poesia.IV.1.Testo.txt  MIDIA
# 3           Personali.IV.5.Testo.txt  MIDIA
# 4          Espositivi.IV.4.Testo.txt  MIDIA
# ...                              ...    ...
# 206                 JSIatterrire.csv    JSI
# 1043  JSIspaventare_randomsample.csv    JSI
# 449            JSImostruosamente.csv    JSI
# 200                 JSIatterrire.csv    JSI
# 31    JSIangosciare_randomsample.csv    JSI
#
#                                    author                        title  \
# 0                  Faustina Maratti Zappi                       Poesie
# 1               Giambattista Felice Zappi                       Poesie
# 2     Giuseppe Paolucci (Alessi Cillenio)                       Poesie
# 3                       Lorenzo Magalotti  Lettere odorose (1693-1705)
# 4              Ludovico Antonio Muratori            Antichità italiane
# ...                                   ...                          ...
# 206                         repubblica.it                repubblica.it
# 1043                            zazoom.it                    zazoom.it
# 449                         repubblica.it                repubblica.it
# 200                        doppiozero.com               doppiozero.com
# 31                        agenzianova.com              agenzianova.com
#
#         year   text_type    words  \
# 0     1700.0      poesia   3184.0
# 1     1700.0      poesia   6113.0
# 2     1700.0      poesia  10862.0
# 3     1700.0   personale   8374.0
# 4     1700.0  espositivo   8990.0
# ...      ...         ...      ...
# 206   2021.0         web     48.0
# 1043  2021.0         web     35.0
# 449   2021.0         web     34.0
# 200   2021.0         web     42.0
# 31    2021.0         web     35.0
#
#                                                    text  \
# 0     IV. 4. Rime degli Arcadi: Aglauro Cidonia (Fau...
# 1     IV. 11. Rime degli arcadi: Tirsi Leucasio (Gio...
# 2     IV. 1. Rime degli Arcadi: Alessi Cillenio (Giu...
# 3     IV. 5. Lorenzo Magalotti, Lettere odorose (169...
# 4     ﻿IV. 4. Ludovico Antonio Muratori, Antichità i...
# ...                                                 ...
# 206   , si dedica da anni all''avventura fantasy-que...
# 1043  francese â€~Footmercatoâ€™, nella giornata di ...
# 449   linkmotorssalerno@gmail.com,LINK MOTORS SALERN...
# 200    Un crescendo appartiene alla tonalità emotiva...
# 31    annunciato di aver costituito una società per ...
#
#                                            cleaned_text
# 0     iv.  . rime degli arcadi: aglauro cidonia  fau...
# 1     iv.   . rime degli arcadi: tirsi leucasio  gio...
# 2     iv.  . rime degli arcadi: alessi cillenio  giu...
# 3     iv.  . lorenzo magalotti, lettere odorose     ...
# 4      iv.  . ludovico antonio muratori, antichità i...
# ...                                                 ...
# 206   , si dedica da anni all  avventura fantasy que...
# 1043  francese    footmercato   , nella giornata di ...
# 449   linkmotorssalerno gmail. com, link motors sale...
# 200    un crescendo appartiene alla tonalità emotiva...
# 31    annunciato di aver costituito una società per ...
#
# [431959 rows x 9 columns]

# %%
# speichern

df_final.to_csv('Korpus/corpus_complete.csv', encoding='utf-8', index=False)
