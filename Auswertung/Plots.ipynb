# %% [markdown]
# # Visualisierungen der manuellen Analyse

# %%
from matplotlib import pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### terribilmente

# %%
periods = ['1700-1750', '1751-1800', '1801-1850', '1851-1900', '1901-1950', '1951-2000', '2001-2021']

# %%
CU = [7, 6, 13, 38, 23, 1, 8]
BU = [0, 2, 10, 38, 51, 12, 19]
NU = [0, 0, 5, 23, 49, 100, 89]
PU = [0, 0, 0, 0, 2, 12, 9]

# %%
plt.figure(figsize=[14,7])
plt.style.use('seaborn-whitegrid')

data = np.array([CU, BU, NU, PU])
labels = ['konventionell', 'ambig', 'intensivierend', 'positiv intensivierend']
colors = ['#00004d', '#0000FF', '#008fcc', '#80dfff']

X = np.arange(data.shape[1])
for i in range(data.shape[0]):
    plt.bar(X, data[i],bottom = np.sum(data[:i], axis=0),label=labels[i % len(labels)], color=colors[i % len(colors)])

x_indexes = np.arange(len(periods))
plt.xticks(ticks=x_indexes, labels=periods, rotation=45, horizontalalignment='right', fontsize='small')
#plt.xlabel('Zeiträume')
#plt.ylabel('Use Case')
plt.ylim(0, 150)
plt.legend(loc='upper left', fontsize='large')

plt.tight_layout()
plt.margins(0.2, 0.15)

#plt.savefig('Plots/terribilmente_usecases.png')
plt.show()

# %% [markdown]
# ### spaventosamente

# %%
periods = ['1700--1850', '1851-1900', '1901-1950', '1951-2000', '2001-2021']

# %%
CU = [6, 17, 21, 7, 6]
BU = [2, 11, 50, 29, 20]
NU = [0, 0, 33, 82, 88]
PU = [0, 0, 3, 6, 11]

# %%
plt.figure(figsize=[14,7])
plt.style.use('seaborn-whitegrid')

data = np.array([CU, BU, NU, PU])
labels = ['konventionell', 'ambig', 'intensivierend', 'positiv intensivierend']
colors = ['#00004d', '#0000FF', '#008fcc', '#80dfff']

X = np.arange(data.shape[1])
for i in range(data.shape[0]):
    plt.bar(X, data[i],bottom = np.sum(data[:i], axis=0),label=labels[i % len(labels)], color=colors[i % len(colors)])

x_indexes = np.arange(len(periods))
plt.xticks(ticks=x_indexes, labels=periods, rotation=45, horizontalalignment='right', fontsize='small')
#plt.xlabel('Zeiträume')
#plt.ylabel('Use Case')
plt.ylim(0, 150)
plt.legend(loc='upper left', fontsize='large')

plt.tight_layout()
plt.margins(0.2, 0.15)

#plt.savefig('Plots/spaventosamente_usecases.png')
plt.show()

# %% [markdown]
# ### orribilmente

# %%
periods = ['1700-1750', '1751-1800', '1801-1850', '1851-1900', '1901-1950', '1951-2000', '2001-2021']

# %%
CU = [12, 9, 20, 17, 18, 29, 42]
BU = [5, 5, 17, 50, 42, 45, 50]
NU = [0, 1, 6, 32, 55, 51, 33]
PU = [0, 0, 0, 0, 1, 0, 0]

# %%
plt.figure(figsize=[14,7])
plt.style.use('seaborn-whitegrid')

data = np.array([CU, BU, NU, PU])
labels = ['konventionell', 'ambig', 'intensivierend', 'positiv intensivierend']
colors = ['#00004d', '#0000FF', '#008fcc', '#80dfff']

X = np.arange(data.shape[1])
for i in range(data.shape[0]):
    plt.bar(X, data[i],bottom = np.sum(data[:i], axis=0),label=labels[i % len(labels)], color=colors[i % len(colors)])

x_indexes = np.arange(len(periods))
plt.xticks(ticks=x_indexes, labels=periods, rotation=45, horizontalalignment='right', fontsize='small')
#plt.xlabel('Zeiträume')
#plt.ylabel('Use Case')
plt.ylim(0, 150)
plt.legend(loc='upper left', fontsize='large')

plt.tight_layout()
plt.margins(0.2, 0.15)

#plt.savefig('Plots/orribilmente_usecases.png')
plt.show()
