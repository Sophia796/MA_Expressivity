# %% [markdown]
# # Korpus normalisieren / ausbalancieren

# %%
from collections import Counter
from matplotlib import pyplot as plt
from matplotlib import ticker
import glob
import math
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

# %%
# großes DF einlesen 

df_bigger = pd.read_csv('Korpus/corpus_complete.csv', sep=',', encoding='utf-8')

# %%
df_bigger.head()
# Out:
#                          doc source                               author  \
# 0      Poesia.IV.4.Testo.txt  MIDIA               Faustina Maratti Zappi
# 1     Poesia.IV.11.Testo.txt  MIDIA            Giambattista Felice Zappi
# 2      Poesia.IV.1.Testo.txt  MIDIA  Giuseppe Paolucci (Alessi Cillenio)
# 3   Personali.IV.5.Testo.txt  MIDIA                    Lorenzo Magalotti
# 4  Espositivi.IV.4.Testo.txt  MIDIA           Ludovico Antonio Muratori
#
#                          title    year     period   text_type  \
# 0                       Poesie  1700.0  1700-1750      poesia
# 1                       Poesie  1700.0  1700-1750      poesia
# 2                       Poesie  1700.0  1700-1750      poesia
# 3  Lettere odorose (1693-1705)  1700.0  1700-1750   personale
# 4           Antichità italiane  1700.0  1700-1750  espositivo
#
#                                                 text    words
# 0  IV. 4. Rime degli Arcadi: Aglauro Cidonia (Fau...   3184.0
# 1  IV. 11. Rime degli arcadi: Tirsi Leucasio (Gio...   6113.0
# 2  IV. 1. Rime degli Arcadi: Alessi Cillenio (Giu...  10862.0
# 3  IV. 5. Lorenzo Magalotti, Lettere odorose (169...   8374.0
# 4  ﻿IV. 4. Ludovico Antonio Muratori, Antichità i...   8990.0

# %%
df_bigger.shape
# Out:
# (431959, 9)

# %% [markdown]
# ## Gewichtung der Texte, die die Kandidaten und die Quelldomäne enthalten

# %%
def clean_text(text):
    clean = re.sub('[^A-Za-z_àÀèÈìÌòÒùÙáÁéÉíÍóÓúÚ]',' ', text).lower()
    return clean

# %%
df_bigger['filtered_text'] = df_bigger['text'].astype(str).apply(clean_text)

# %%
adverbs = ['atrocemente', 'formidabilmente', 'mostruosamente', 'orrendamente', 
            'orribilmente', 'spaventosamente', 'terribilmente', 'tremendamente']

domaine = ['angoscia', 'angosciare', 'ansia', 'atterrire', 'panico', 'paura', 'raccapricciare', 
           'raccapriccio', 'schifo', 'sgomentare', 'sgomento', 'spaventare', 'spavento', 'terrore']

# %%
def is_word(filtered_text):
    if any(word in filtered_text for word in adverbs):         # größte Gewichtung bei den Adverbien 
        x = 1                                                      
    elif any(word in filtered_text for word in domaine):       # ein bisschen Gewichtung bei der Quelldomäne
        x = 0.8                                             
    else:
        x = 0.5
    return x

# %%
df_bigger['weight'] = df_bigger['filtered_text'].astype(str).apply(is_word)

# %%
df_bigger[df_bigger['weight'] == 1]
# Out:
#                                         doc           source  \
# 17                            ita000099.txt        ItaDraCor
# 20                        BibItDiversi4.txt            BibIt
# 21                        BibItDiversi6.txt            BibIt
# 22                        BibItDiversi2.txt            BibIt
# 23                        BibItDiversi3.txt            BibIt
# ...                                     ...              ...
# 416064       ita_news_2020_1M-sentences.txt  Corpora Italian
# 423633  ita_newscrawl_2020_1M-sentences.txt  Corpora Italian
# 431877                   JSIatrocemente.csv              JSI
# 431921                JSImostruosamente.csv              JSI
# 431956                JSImostruosamente.csv              JSI
#
#                                                    author  \
# 17                                      Annibale Marchese
# 20                                                diversi
# 21                                                diversi
# 22                                                diversi
# 23                                                diversi
# ...                                                   ...
# 416064  https://www.panorama.it/abbonati/costume/souti...
# 423633  https://gazzettadireggio.gelocal.it/reggio/cro...
# 431877                                          zazoom.it
# 431921                                tuttomercatoweb.com
# 431956                                      repubblica.it
#
#                                                     title    year     period  \
# 17                                              Il Crispo  1715.0  1700-1750
# 20                       Rime degli Arcadi / tomo secondo  1716.0  1700-1750
# 21                         Rime degli Arcadi / tomo terzo  1716.0  1700-1750
# 22                        Rime degli Arcadi / tomo quarto  1717.0  1700-1750
# 23                        Rime degli Arcadi / tomo quinto  1717.0  1700-1750
# ...                                                   ...     ...        ...
# 416064  https://www.panorama.it/abbonati/costume/souti...  2020.0  2001-2021
# 423633  https://gazzettadireggio.gelocal.it/reggio/cro...  2020.0  2001-2021
# 431877                                          zazoom.it  2021.0  2001-2021
# 431921                                tuttomercatoweb.com  2021.0  2001-2021
# 431956                                      repubblica.it  2021.0  2001-2021
#
#        text_type                                               text    words  \
# 17        teatro  Degno mio germe, per cui sol vedrassi\nA l'org...  16961.0
# 20        poesia  Aci Delpusiano\n1\nDov'è quella famosa, alta, ...  76203.0
# 21        poesia  Adelindo Gerenio\n1\nVissi lunga stagione al M...  79958.0
# 22        poesia  Adalsio Metoneo\n1\nQuesti, più assai che del ...  74529.0
# 23        poesia  Acasto Lampeatico\n1\nAhimè, che il carro mio ...  74909.0
# ...          ...                                                ...      ...
# 416064    stampa             Contenextus hai tremendamente ragione.      4.0
# 423633    stampa  Approda forse alla panchina di Villa Durazzo P...     22.0
# 431877       web  italiani, determinato nel voler far luce sul f...     37.0
# 431921       web  a Fifa e federazioni nazionali) si erge a gran...     40.0
# 431956       web  linkmotorssalerno@gmail.com,LINK MOTORS SALERN...     34.0
#
#                                             filtered_text  weight
# 17      degno mio germe  per cui sol vedrassi a l orgo...     1.0
# 20      aci delpusiano   dov è quella famosa  alta  su...     1.0
# 21      adelindo gerenio   vissi lunga stagione al mon...     1.0
# 22      adalsio metoneo   questi  più assai che del mi...     1.0
# 23      acasto lampeatico   ahimè  che il carro mio fr...     1.0
# ...                                                   ...     ...
# 416064             contenextus hai tremendamente ragione      1.0
# 423633  approda forse alla panchina di villa durazzo p...     1.0
# 431877  italiani  determinato nel voler far luce sul f...     1.0
# 431921  a fifa e federazioni nazionali  si erge a gran...     1.0
# 431956  linkmotorssalerno gmail com link motors salern...     1.0
#
# [4872 rows x 11 columns]

# %% [markdown]
# ## Normalisierung

# %%
# Normalisierung durch zufälliges Ziehen ohne Zurücklegen von Samples (Texten)
# Samplegröße individuell festgegelegt durch Ausprobieren 
# Ziel: ungefähres Übereinstimmen der Tokenanzahl 
# Bevorzugt gewichtete Texte nehmen (siehe oben)

p1 = df_bigger[df_bigger['period']=='1700-1750']
p2 = df_bigger[df_bigger['period']=='1751-1800'].sample(n=1310 , random_state=1, weights='weight')
p3 = df_bigger[df_bigger['period']=='1801-1850'].sample(n=1700 , random_state=1, weights='weight')
p4 = df_bigger[df_bigger['period']=='1851-1900'].sample(n=4420 , random_state=1, weights='weight')
p5 = df_bigger[df_bigger['period']=='1901-1950'].sample(n=11000 , random_state=1, weights='weight')     
p6 = df_bigger[df_bigger['period']=='1951-2000'].sample(n=37500 , random_state=1, weights='weight')
p7 = df_bigger[df_bigger['period']=='2001-2021'].sample(n=93000 , random_state=1, weights='weight')

# Zusammenfügen der Zeiträume und Samples zu einem neuen Dataframe
df_norm = pd.concat([p1, p2, p3, p4, p5, p6, p7])

# %%
df_norm.head()
# Out:
#                          doc source                               author  \
# 0      Poesia.IV.4.Testo.txt  MIDIA               Faustina Maratti Zappi
# 1     Poesia.IV.11.Testo.txt  MIDIA            Giambattista Felice Zappi
# 2      Poesia.IV.1.Testo.txt  MIDIA  Giuseppe Paolucci (Alessi Cillenio)
# 3   Personali.IV.5.Testo.txt  MIDIA                    Lorenzo Magalotti
# 4  Espositivi.IV.4.Testo.txt  MIDIA           Ludovico Antonio Muratori
#
#                          title    year     period   text_type  \
# 0                       Poesie  1700.0  1700-1750      poesia
# 1                       Poesie  1700.0  1700-1750      poesia
# 2                       Poesie  1700.0  1700-1750      poesia
# 3  Lettere odorose (1693-1705)  1700.0  1700-1750   personale
# 4           Antichità italiane  1700.0  1700-1750  espositivo
#
#                                                 text    words  \
# 0  IV. 4. Rime degli Arcadi: Aglauro Cidonia (Fau...   3184.0
# 1  IV. 11. Rime degli arcadi: Tirsi Leucasio (Gio...   6113.0
# 2  IV. 1. Rime degli Arcadi: Alessi Cillenio (Giu...  10862.0
# 3  IV. 5. Lorenzo Magalotti, Lettere odorose (169...   8374.0
# 4  ﻿IV. 4. Ludovico Antonio Muratori, Antichità i...   8990.0
#
#                                        filtered_text  weight
# 0  iv     rime degli arcadi  aglauro cidonia  fau...     0.5
# 1  iv      rime degli arcadi  tirsi leucasio  gio...     0.8
# 2  iv     rime degli arcadi  alessi cillenio  giu...     0.8
# 3  iv     lorenzo magalotti  lettere odorose     ...     0.8
# 4   iv     ludovico antonio muratori  antichità i...     0.5

# %%
df_norm.shape
# Out:
# (155605, 11)

# %% [markdown]
# ### Anzahl der Texte pro Zeitraum

# %%
periods_norm = list(df_norm['period'].unique())
per_len_norm ={i: len(df_norm[df_norm['period']==i]) for i in periods_norm }
per_len_norm
# Out:
# {'1700-1750': 6675,
#  '1751-1800': 1310,
#  '1801-1850': 1700,
#  '1851-1900': 4420,
#  '1901-1950': 11000,
#  '1951-2000': 37500,
#  '2001-2021': 93000}

# %%
plt.figure(figsize=[14,7])
plt.style.use('seaborn-whitegrid')

x_indexes = np.arange(len(periods_norm))
plt.bar(x_indexes, per_len_norm.values(), label='Textanzahl', width=0.8, color='b')
plt.xticks(ticks = x_indexes, labels = per_len_norm.keys(), rotation=45, horizontalalignment='right')
plt.xlabel('Zeiträume')
plt.ylabel('Textanzahl')

#plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.tight_layout()
plt.margins(0.2, 0.15)

for i, j in zip(x_indexes, per_len_norm.values()):
       plt.annotate(j, xy=(i,j), xycoords='data', verticalalignment='bottom', horizontalalignment='center', 
                    fontweight='demi', fontsize='small')

#plt.savefig('Plots/corpusnorm_textanzahl.png')
plt.show()

# %% [markdown]
# ### Anzahl der Tokens pro Zeitraum

# %%
sum_words_norm = {i: math.trunc(sum(df_norm[df_norm['period']==i].words)) for i in periods_norm}
sum_words_norm
# Out:
# {'1700-1750': 2208509,
#  '1751-1800': 2221781,
#  '1801-1850': 2235345,
#  '1851-1900': 2264137,
#  '1901-1950': 2217924,
#  '1951-2000': 2287311,
#  '2001-2021': 2290584}

# %%
plt.figure(figsize=[14,7])
plt.style.use('seaborn-whitegrid')

x_indexes = np.arange(len(sum_words_norm))
plt.bar(x_indexes, sum_words_norm.values(), label='Tokenanzahl', width=0.8, color='b')
plt.xticks(ticks = x_indexes, labels = sum_words_norm.keys(), rotation=45, horizontalalignment='right', fontsize='small')
plt.xlabel('Zeiträume')
plt.ylabel('Tokenanzahl')
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ylim(0, 3000000)

plt.tight_layout()
plt.margins(0.2, 0.15)

for i, j in zip(x_indexes, sum_words_norm.values()):
       plt.annotate(j, xy=(i,j), xycoords='data', verticalalignment='bottom', horizontalalignment='center', 
                    fontweight='demi', fontsize='small')
        
#plt.savefig('Plots/corpusnorm_tokenanzahl.png')
plt.show()

# %% [markdown]
# ### Verteilung der Texttypen auf die Zeiträume

# %%
period_frames = []

# %%
# Teilframes pro Zeitraum erstellen

df_periods = dict(tuple(df_norm.groupby(by='period')))

for df, period in zip(df_periods, periods_norm):
    df_period = df_periods[period]
    period_frames.append(df_period)

# %%
periods_texttypes = {}

# %%
# Anzahl der Texte pro Texttyp pro Zeitraum

for df, period in zip(period_frames, periods_norm):
    texttypes = df.groupby(by='text_type')
    types = texttypes.groups
    
    periods_texttypes[period] = {key : len(value) for key, value in types.items()}

# %%
periods_texttypes
# Out:
# {'1700-1750': {'espositivo': 15,
#   'personale': 19,
#   'poesia': 13,
#   'prosa letteraria': 6603,
#   'teatro': 25},
#  '1751-1800': {'espositivo': 27,
#   'personale': 12,
#   'poesia': 18,
#   'prosa letteraria': 1216,
#   'teatro': 37},
#  '1801-1850': {'espositivo': 35,
#   'personale': 11,
#   'poesia': 15,
#   'prosa letteraria': 1636,
#   'teatro': 3},
#  '1851-1900': {'espositivo': 7,
#   'personale': 7,
#   'poesia': 6,
#   'prosa letteraria': 4392,
#   'stampa': 4,
#   'teatro': 4},
#  '1901-1950': {'espositivo': 22,
#   'personale': 3,
#   'poesia': 11,
#   'prosa letteraria': 10932,
#   'stampa': 27,
#   'teatro': 5},
#  '1951-2000': {'dialogo': 4,
#   'espositivo': 15,
#   'prosa letteraria': 277,
#   'stampa': 37204},
#  '2001-2021': {'dialogo': 1,
#   'prosa letteraria': 3,
#   'stampa': 77518,
#   'web': 15478}}

# %%
periods_texttypes_token = {}

# %%
# Anzahl der Tokens pro Texttyp pro Zeitraum

for df, period in zip(period_frames, periods_norm):
    words = {i: math.trunc(sum(df[df['text_type']==i].words)) for i in list(df['text_type'].unique())}
    periods_texttypes_token[period] = words

# %%
periods_texttypes_token
# Out:
# {'1700-1750': {'poesia': 512572,
#   'personale': 236165,
#   'espositivo': 877862,
#   'prosa letteraria': 330533,
#   'teatro': 251377},
#  '1751-1800': {'prosa letteraria': 121224,
#   'personale': 352852,
#   'espositivo': 1170310,
#   'poesia': 189453,
#   'teatro': 387942},
#  '1801-1850': {'prosa letteraria': 602751,
#   'espositivo': 1047829,
#   'teatro': 33182,
#   'personale': 415304,
#   'poesia': 136279},
#  '1851-1900': {'prosa letteraria': 1622752,
#   'personale': 98322,
#   'espositivo': 462417,
#   'teatro': 31220,
#   'poesia': 46029,
#   'stampa': 3397},
#  '1901-1950': {'prosa letteraria': 1516994,
#   'espositivo': 478621,
#   'stampa': 10574,
#   'poesia': 99802,
#   'personale': 79931,
#   'teatro': 32002},
#  '1951-2000': {'stampa': 1683628,
#   'prosa letteraria': 550459,
#   'espositivo': 42229,
#   'dialogo': 10995},
#  '2001-2021': {'stampa': 1746375,
#   'web': 379320,
#   'prosa letteraria': 164874,
#   'dialogo': 15}}

# %%
espositivo = []
dialogo = []
poesia = []
personale = []
prosa_lett = []
stampa = []
teatro = []
web = []

# %%
# Werte des Texttyps rausziehen und in Liste speichern 

for i in periods_texttypes_token:
    
    esp = periods_texttypes_token.get(i, {}).get('espositivo')
    espositivo.append(esp)
    
    di = periods_texttypes_token.get(i, {}).get('dialogo')
    dialogo.append(di)
    
    po = periods_texttypes_token.get(i, {}).get('poesia')
    poesia.append(po)
    
    per = periods_texttypes_token.get(i, {}).get('personale')
    personale.append(per)
    
    prolet = periods_texttypes_token.get(i, {}).get('prosa letteraria')
    prosa_lett.append(prolet)
    
    st = periods_texttypes_token.get(i, {}).get('stampa')
    stampa.append(st)
    
    tea = periods_texttypes_token.get(i, {}).get('teatro')
    teatro.append(tea)
    
    w = periods_texttypes_token.get(i, {}).get('web')
    web.append(w)

# %%
# None mit 0 ersetzen

espositivo = [0 if v is None else v for v in espositivo]
dialogo = [0 if v is None else v for v in dialogo]
poesia = [0 if v is None else v for v in poesia]
personale = [0 if v is None else v for v in personale]
prosa_lett = [0 if v is None else v for v in prosa_lett]
stampa = [0 if v is None else v for v in stampa]
teatro = [0 if v is None else v for v in teatro]
web = [0 if v is None else v for v in web]

# %%
print(espositivo)
print(dialogo)
print(personale)
print(poesia)
print(prosa_lett)
print(stampa)
print(teatro)
print(web)
# Out:
# [877862, 1170310, 1047829, 462417, 478621, 42229, 0]
# [0, 0, 0, 0, 0, 10995, 15]
# [236165, 352852, 415304, 98322, 79931, 0, 0]
# [512572, 189453, 136279, 46029, 99802, 0, 0]
# [330533, 121224, 602751, 1622752, 1516994, 550459, 164874]
# [0, 0, 0, 3397, 10574, 1683628, 1746375]
# [251377, 387942, 33182, 31220, 32002, 0, 0]
# [0, 0, 0, 0, 0, 0, 379320]

# %%
# Verteilung der Texttypen auf die Zeiträume

plt.figure(figsize=[14,7])
plt.style.use('seaborn-whitegrid')

data = np.array([espositivo, dialogo, personale, poesia, prosa_lett, stampa, teatro, web])
labels = ['espositivo', 'dialogo', 'personale', 'poesia', 'prosa letteraria', 'stampa', 'teatro', 'web']
colors = ['#00004d','#380474', '#000099', '#0000FF', '#008fcc', '#0BB5FF', '#80dfff', '#BFEFFF']

X = np.arange(data.shape[1])
for i in range(data.shape[0]):
    plt.bar(X, data[i],bottom = np.sum(data[:i], axis=0),label=labels[i % len(labels)], color=colors[i % len(colors)])

x_indexes = np.arange(len(periods_norm))
plt.xticks(ticks=x_indexes, labels=periods_norm, rotation=45, horizontalalignment='right', fontsize='small')
plt.xlabel('Zeiträume')
plt.ylabel('Tokenanzahl')
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ylim(0, 3000000)
plt.legend(loc='upper left', fontsize='small')

plt.tight_layout()
plt.margins(0.2, 0.2)

for i, j in zip(x_indexes, sum_words_norm.values()):
       plt.annotate(j, xy=(i,j), xycoords='data', verticalalignment='bottom', horizontalalignment='center', 
                    fontweight='demi', fontsize='small')

#plt.savefig('Plots/corpusnorm_tokenanzahl_texttypes.png')
plt.show()

# %%
# normalisiertes Korpus speichern

df_norm.to_csv('Korpus/corpus_norm.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Kandidaten im normalisierten, lemmatisierten Korpus

# %%
# wieder einlesen 

df_norm = pd.read_csv('Korpus/corpus_norm.csv', sep=',', encoding='utf-8')

# %%
df_norm.head()
# Out:
#                          doc source                               author  \
# 0      Poesia.IV.4.Testo.txt  MIDIA               Faustina Maratti Zappi
# 1     Poesia.IV.11.Testo.txt  MIDIA            Giambattista Felice Zappi
# 2      Poesia.IV.1.Testo.txt  MIDIA  Giuseppe Paolucci (Alessi Cillenio)
# 3   Personali.IV.5.Testo.txt  MIDIA                    Lorenzo Magalotti
# 4  Espositivi.IV.4.Testo.txt  MIDIA           Ludovico Antonio Muratori
#
#                          title    year     period   text_type  \
# 0                       Poesie  1700.0  1700-1750      poesia
# 1                       Poesie  1700.0  1700-1750      poesia
# 2                       Poesie  1700.0  1700-1750      poesia
# 3  Lettere odorose (1693-1705)  1700.0  1700-1750   personale
# 4           Antichità italiane  1700.0  1700-1750  espositivo
#
#                                                 text    words  \
# 0  IV. 4. Rime degli Arcadi: Aglauro Cidonia (Fau...   3184.0
# 1  IV. 11. Rime degli arcadi: Tirsi Leucasio (Gio...   6113.0
# 2  IV. 1. Rime degli Arcadi: Alessi Cillenio (Giu...  10862.0
# 3  IV. 5. Lorenzo Magalotti, Lettere odorose (169...   8374.0
# 4  ﻿IV. 4. Ludovico Antonio Muratori, Antichità i...   8990.0
#
#                                        filtered_text  weight
# 0  iv     rime degli arcadi  aglauro cidonia  fau...     0.5
# 1  iv      rime degli arcadi  tirsi leucasio  gio...     0.8
# 2  iv     rime degli arcadi  alessi cillenio  giu...     0.8
# 3  iv     lorenzo magalotti  lettere odorose     ...     0.8
# 4   iv     ludovico antonio muratori  antichità i...     0.5

# %%
df_norm.shape
# Out:
# (155605, 11)

# %%
df_norm.text = df_norm.text.fillna('')

# %%
# Teilframes pro Zeitraum erstellen

period_frames = []
periods = list(df_norm['period'].unique())
df_periods = dict(tuple(df_norm.groupby(by='period')))

for df, period in zip(df_periods, periods):
    df_period = df_periods[period]
    period_frames.append(df_period)

# %%
# Funktion, die bestimmte Wörter zählt
# Achtung: noch nicht lemmatisiert! Nach Lemmatisierung wiederholen!

def count_keywords(df, keywords):
    keyword_dict = {w:w.replace(' ', '_') for w in keywords}

    corpus = ' '.join(df.text).lower()                     
    for w,w2 in keyword_dict.items():
        corpus = corpus.replace(w,w2)

    all_counts = Counter(corpus.split())
    final_counts = {w:all_counts[w2] for w,w2 in keyword_dict.items()}
    return final_counts

# %%
# mögliche Kandidaten

keywords = ['atrocemente', 'formidabilmente', 'mostruosamente', 'orrendamente', 
            'orribilmente', 'spaventosamente', 'terribilmente', 'tremendamente', 
            'molto', 'angoscia', 'angosciare', 'ansia', 'atterrire', 'panico', 
            'paura', 'raccapricciare', 'raccapriccio', 'schifo', 'sgomentare', 
            'sgomento', 'spaventare', 'spavento', 'terrore', 'domani', 'finora', 
            'ieri', 'oggi', 'presto', 'raramente', 'sempre', 'spesso']

# %%
candidates = {}

for df, period in zip(period_frames, periods):
    res = count_keywords(df, keywords)
    candidates[period] = res

# %%
candidates
# Out:
# {'1700-1750': {'atrocemente': 2,
#   'formidabilmente': 0,
#   'mostruosamente': 2,
#   'orrendamente': 1,
#   'orribilmente': 19,
#   'spaventosamente': 9,
#   'terribilmente': 13,
#   'tremendamente': 0,
#   'molto': 1303,
#   'angoscia': 3,
#   'angosciare': 0,
#   'ansia': 0,
#   'atterrire': 13,
#   'panico': 9,
#   'paura': 108,
#   'raccapricciare': 0,
#   'raccapriccio': 1,
#   'schifo': 7,
#   'sgomentare': 0,
#   'sgomento': 3,
#   'spaventare': 4,
#   'spavento': 148,
#   'terrore': 107,
#   'domani': 25,
#   'finora': 224,
#   'ieri': 13,
#   'oggi': 479,
#   'presto': 187,
#   'raramente': 8,
#   'sempre': 1887,
#   'spesso': 431},
#  '1751-1800': {'atrocemente': 2,
#   'formidabilmente': 0,
#   'mostruosamente': 0,
#   'orrendamente': 1,
#   'orribilmente': 15,
#   'spaventosamente': 0,
#   'terribilmente': 11,
#   'tremendamente': 0,
#   'molto': 1501,
#   'angoscia': 12,
#   'angosciare': 0,
#   'ansia': 0,
#   'atterrire': 4,
#   'panico': 9,
#   'paura': 98,
#   'raccapricciare': 0,
#   'raccapriccio': 7,
#   'schifo': 25,
#   'sgomentare': 0,
#   'sgomento': 3,
#   'spaventare': 3,
#   'spavento': 59,
#   'terrore': 77,
#   'domani': 121,
#   'finora': 166,
#   'ieri': 65,
#   'oggi': 393,
#   'presto': 335,
#   'raramente': 52,
#   'sempre': 2425,
#   'spesso': 546},
#  '1801-1850': {'atrocemente': 11,
#   'formidabilmente': 0,
#   'mostruosamente': 1,
#   'orrendamente': 5,
#   'orribilmente': 30,
#   'spaventosamente': 1,
#   'terribilmente': 16,
#   'tremendamente': 0,
#   'molto': 1092,
#   'angoscia': 33,
#   'angosciare': 1,
#   'ansia': 14,
#   'atterrire': 19,
#   'panico': 12,
#   'paura': 148,
#   'raccapricciare': 3,
#   'raccapriccio': 16,
#   'schifo': 10,
#   'sgomentare': 13,
#   'sgomento': 8,
#   'spaventare': 19,
#   'spavento': 101,
#   'terrore': 144,
#   'domani': 138,
#   'finora': 89,
#   'ieri': 184,
#   'oggi': 613,
#   'presto': 341,
#   'raramente': 17,
#   'sempre': 2369,
#   'spesso': 526},
#  '1851-1900': {'atrocemente': 42,
#   'formidabilmente': 7,
#   'mostruosamente': 13,
#   'orrendamente': 20,
#   'orribilmente': 106,
#   'spaventosamente': 21,
#   'terribilmente': 60,
#   'tremendamente': 27,
#   'molto': 1619,
#   'angoscia': 98,
#   'angosciare': 0,
#   'ansia': 65,
#   'atterrire': 13,
#   'panico': 16,
#   'paura': 398,
#   'raccapricciare': 10,
#   'raccapriccio': 78,
#   'schifo': 52,
#   'sgomentare': 8,
#   'sgomento': 100,
#   'spaventare': 19,
#   'spavento': 135,
#   'terrore': 154,
#   'domani': 254,
#   'finora': 117,
#   'ieri': 161,
#   'oggi': 439,
#   'presto': 403,
#   'raramente': 49,
#   'sempre': 2566,
#   'spesso': 459},
#  '1901-1950': {'atrocemente': 65,
#   'formidabilmente': 13,
#   'mostruosamente': 34,
#   'orrendamente': 34,
#   'orribilmente': 158,
#   'spaventosamente': 105,
#   'terribilmente': 222,
#   'tremendamente': 40,
#   'molto': 1322,
#   'angoscia': 211,
#   'angosciare': 0,
#   'ansia': 261,
#   'atterrire': 6,
#   'panico': 55,
#   'paura': 544,
#   'raccapricciare': 11,
#   'raccapriccio': 100,
#   'schifo': 111,
#   'sgomentare': 6,
#   'sgomento': 255,
#   'spaventare': 18,
#   'spavento': 195,
#   'terrore': 248,
#   'domani': 444,
#   'finora': 189,
#   'ieri': 332,
#   'oggi': 772,
#   'presto': 392,
#   'raramente': 156,
#   'sempre': 2643,
#   'spesso': 604},
#  '1951-2000': {'atrocemente': 79,
#   'formidabilmente': 5,
#   'mostruosamente': 72,
#   'orrendamente': 75,
#   'orribilmente': 89,
#   'spaventosamente': 91,
#   'terribilmente': 140,
#   'tremendamente': 86,
#   'molto': 1977,
#   'angoscia': 284,
#   'angosciare': 2,
#   'ansia': 244,
#   'atterrire': 5,
#   'panico': 257,
#   'paura': 661,
#   'raccapricciare': 3,
#   'raccapriccio': 98,
#   'schifo': 169,
#   'sgomentare': 3,
#   'sgomento': 212,
#   'spaventare': 43,
#   'spavento': 140,
#   'terrore': 343,
#   'domani': 642,
#   'finora': 572,
#   'ieri': 1804,
#   'oggi': 2153,
#   'presto': 646,
#   'raramente': 291,
#   'sempre': 3144,
#   'spesso': 1094},
#  '2001-2021': {'atrocemente': 124,
#   'formidabilmente': 100,
#   'mostruosamente': 125,
#   'orrendamente': 130,
#   'orribilmente': 121,
#   'spaventosamente': 123,
#   'terribilmente': 128,
#   'tremendamente': 124,
#   'molto': 2113,
#   'angoscia': 115,
#   'angosciare': 3,
#   'ansia': 121,
#   'atterrire': 7,
#   'panico': 159,
#   'paura': 423,
#   'raccapricciare': 5,
#   'raccapriccio': 112,
#   'schifo': 118,
#   'sgomentare': 5,
#   'sgomento': 99,
#   'spaventare': 25,
#   'spavento': 108,
#   'terrore': 163,
#   'domani': 504,
#   'finora': 217,
#   'ieri': 998,
#   'oggi': 1684,
#   'presto': 302,
#   'raramente': 83,
#   'sempre': 2544,
#   'spesso': 568}}

# %%
table = pd.DataFrame.from_dict(candidates, orient='index')
table
# Out:
#            atrocemente  formidabilmente  mostruosamente  orrendamente  \
# 1700-1750            2                0               2             1
# 1751-1800            2                0               0             1
# 1801-1850           11                0               1             5
# 1851-1900           42                7              13            20
# 1901-1950           65               13              34            34
# 1951-2000           79                5              72            75
# 2001-2021          124              100             125           130
#
#            orribilmente  spaventosamente  terribilmente  tremendamente  molto  \
# 1700-1750            19                9             13              0   1303
# 1751-1800            15                0             11              0   1501
# 1801-1850            30                1             16              0   1092
# 1851-1900           106               21             60             27   1619
# 1901-1950           158              105            222             40   1322
# 1951-2000            89               91            140             86   1977
# 2001-2021           121              123            128            124   2113
#
#            angoscia  ...  spavento  terrore  domani  finora  ieri  oggi  \
# 1700-1750         3  ...       148      107      25     224    13   479
# 1751-1800        12  ...        59       77     121     166    65   393
# 1801-1850        33  ...       101      144     138      89   184   613
# 1851-1900        98  ...       135      154     254     117   161   439
# 1901-1950       211  ...       195      248     444     189   332   772
# 1951-2000       284  ...       140      343     642     572  1804  2153
# 2001-2021       115  ...       108      163     504     217   998  1684
#
#            presto  raramente  sempre  spesso
# 1700-1750     187          8    1887     431
# 1751-1800     335         52    2425     546
# 1801-1850     341         17    2369     526
# 1851-1900     403         49    2566     459
# 1901-1950     392        156    2643     604
# 1951-2000     646        291    3144    1094
# 2001-2021     302         83    2544     568
#
# [7 rows x 31 columns]

# %%
table.to_csv('Korpus/candidates.csv', sep=';')

# %%
df_norm[df_norm['weight'] == 1]
# Out:
#                                        doc        source  \
# 17                           ita000099.txt     ItaDraCor
# 20                       BibItDiversi4.txt         BibIt
# 21                       BibItDiversi6.txt         BibIt
# 22                       BibItDiversi2.txt         BibIt
# 23                       BibItDiversi3.txt         BibIt
# ...                                    ...           ...
# 154334  TT20tremendamente_randomsample.csv  itTenten2020
# 155014              TT20mostruosamente.csv  itTenten2020
# 155100                 TT16atrocemente.csv  itTenten2016
# 155378               IWspaventosamente.csv         itWaC
# 155401                TT20orribilmente.csv  itTenten2020
#
#                                                    author  \
# 17                                      Annibale Marchese
# 20                                                diversi
# 21                                                diversi
# 22                                                diversi
# 23                                                diversi
# ...                                                   ...
# 154334                            accademianuovaitalia.it
# 155014                               viaggiareleggeri.com
# 155100                                     feltrinelli.it
# 155378  http://www.hideout.it/index.php3?page=eventi&i...
# 155401                                        cineblog.it
#
#                                                     title    year     period  \
# 17                                              Il Crispo  1715.0  1700-1750
# 20                       Rime degli Arcadi / tomo secondo  1716.0  1700-1750
# 21                         Rime degli Arcadi / tomo terzo  1716.0  1700-1750
# 22                        Rime degli Arcadi / tomo quarto  1717.0  1700-1750
# 23                        Rime degli Arcadi / tomo quinto  1717.0  1700-1750
# ...                                                   ...     ...        ...
# 154334                            accademianuovaitalia.it  2020.0  2001-2021
# 155014                               viaggiareleggeri.com  2020.0  2001-2021
# 155100                                     feltrinelli.it  2016.0  2001-2021
# 155378  http://www.hideout.it/index.php3?page=eventi&i...  2006.0  2001-2021
# 155401                                        cineblog.it  2020.0  2001-2021
#
#        text_type                                               text    words  \
# 17        teatro  Degno mio germe, per cui sol vedrassi\nA l'org...  16961.0
# 20        poesia  Aci Delpusiano\n1\nDov'è quella famosa, alta, ...  76203.0
# 21        poesia  Adelindo Gerenio\n1\nVissi lunga stagione al M...  79958.0
# 22        poesia  Adalsio Metoneo\n1\nQuesti, più assai che del ...  74529.0
# 23        poesia  Acasto Lampeatico\n1\nAhimè, che il carro mio ...  74909.0
# ...          ...                                                ...      ...
# 154334       web  qui c''è qualcosa di diverso; qualcosa di sott...     40.0
# 155014       web  dell''irrigazione con canna rimarra'' in vigor...     42.0
# 155100       web  . se uno vuole può farlo  "Gli individualisti ...     37.0
# 155378       web  .  Imperdibile dose di arte pura.  Street spir...     37.0
# 155401       web  , uno scienziato dato per morto dopo un sabota...     36.0
#
#                                             filtered_text  weight
# 17      degno mio germe  per cui sol vedrassi a l orgo...     1.0
# 20      aci delpusiano   dov è quella famosa  alta  su...     1.0
# 21      adelindo gerenio   vissi lunga stagione al mon...     1.0
# 22      adalsio metoneo   questi  più assai che del mi...     1.0
# 23      acasto lampeatico   ahimè  che il carro mio fr...     1.0
# ...                                                   ...     ...
# 154334  qui c  è qualcosa di diverso  qualcosa di sott...     1.0
# 155014  dell  irrigazione con canna rimarra   in vigor...     1.0
# 155100    se uno vuole può farlo   gli individualisti ...     1.0
# 155378     imperdibile dose di arte pura   street spir...     1.0
# 155401    uno scienziato dato per morto dopo un sabota...     1.0
#
# [2564 rows x 11 columns]
